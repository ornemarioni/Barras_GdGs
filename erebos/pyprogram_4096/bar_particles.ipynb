# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

# cm0 = np.loadtxt('part_barra2.dat')
# tform1 = cm0[:,1]
# formt = cm0[:,3]

# cm1 = np.loadtxt('part_barra_color.dat')
# ID0 = cm1[:,0]
# ID1 = cm1[:,1]
# ID2 = cm1[:,2]
# ID3 = cm1[:,3]
# ID4 = cm1[:,4]

cm = np.loadtxt('/z/omarioni/pyprogram_4096/newdata/tform_barra.dat')
IDs   = cm[:,0]
tform = cm[:,1]
rn_z0 = cm[:,2]
r0    = cm[:,3]

# mask0 = np.isin(IDs,ID0)
# mask1 = np.isin(IDs,ID1)
# mask2 = np.isin(IDs,ID2)
# mask3 = np.isin(IDs,ID3)
# mask4 = np.isin(IDs,ID4)

r0_com = r0/formt

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
ax.plot(tform,log10(r0),'.', markersize=0.1, color='k')

# ax.plot(tform[mask0],log10(r0[mask0]),'.', markersize=1, color='purple')
# ax.plot(tform[mask1],log10(r0[mask1]),'.', markersize=1, color='r')
# ax.plot(tform[mask2],log10(r0[mask2]),'.', markersize=1, color='b')
# ax.plot(tform[mask3],log10(r0[mask3]),'.', markersize=1, color='g')
# ax.plot(tform[mask4],log10(r0[mask4]),'.', markersize=1, color='orange')

# ax.set_xlim(-50,50)
# ax.set_ylim(-50,50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
ax.minorticks_on()
ax.tick_params( labelsize=22)#, colors='lightgray')
ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')#,colors='w')
ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on')#,colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
#ax.grid(color='lightgray',linestyle=':',which='minor')
ax.set_xlabel(r'$Tiempo\:de\:Formacion\:[Gyr]$', fontsize=26)#, color='lightgray')
ax.set_ylabel(r'$Distancia\:en\:tform\:[kpc]$',fontsize=26)#, color='lightgray')
ax.axhline(y=0.4, color='r', linestyle='--')
# fig.savefig('/home/omarioni/pyprogram_4096/dist_tform.png', dpi = 100)
plt.show()

# fig=plt.figure(2, figsize=(8,8))
# fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
# ax=fig.add_subplot(111)
# #     ax.plot(xn,yn,'.', markersize=0.1, color='k')
# ax.plot(tform,log10(r0),'.', markersize=1, color='k')
# # ax.set_xlim(-50,50)
# # ax.set_ylim(-50,50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
# ax.minorticks_on()
# ax.tick_params( labelsize=22, colors='lightgray')
# ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on',colors='w')
# ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on',colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
# #ax.grid(color='lightgray',linestyle=':',which='minor')
# ax.set_xlabel('Tiempo de Formacion [Gyr]', fontsize=26, color='lightgray')
# ax.set_ylabel('Distancia en tform [kpc]',fontsize=26, color='lightgray')
# plt.show()

# %% [markdown]
# ### Distancias en el tiempo de formación para los nuevos datos

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

# cm0 = np.loadtxt('part_barra2.dat')
# tform1 = cm0[:,1]
# formt = cm0[:,3]

# cm1 = np.loadtxt('part_barra_color.dat')
# ID0 = cm1[:,0]
# ID1 = cm1[:,1]
# ID2 = cm1[:,2]
# ID3 = cm1[:,3]
# ID4 = cm1[:,4]

cm = np.loadtxt('/z/omarioni/pyprogram_4096/newdata/tform_barra.dat')
IDs   = cm[:,0]
tform = cm[:,1]
rn_z0 = cm[:,2]
r0    = cm[:,3]

# r0_com = r0/formt

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
ax.plot(tform,r0,'.', markersize=0.1, color='k')
ax.set_yscale('log')
# ax.set_xlim(-50,50)
ax.set_ylim(0.001,1000)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
ax.minorticks_on()
ax.tick_params( labelsize=22)#, colors='lightgray')
ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')#,colors='w')
ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on')#,colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
#ax.grid(color='lightgray',linestyle=':',which='minor')
ax.set_xlabel(r'$t_{form}\:[Gyr]$', fontsize=26)#, color='lightgray')
ax.set_ylabel(r'$r_{t_{form}}\:[kpc]$',fontsize=26)#, color='lightgray')
ax.axhline(y=2.5, color='r', linestyle='--')
# fig.savefig('/home/omarioni/pyprogram_4096/dist_tform.png', dpi = 100)
plt.show()

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

cm0 = np.loadtxt('part_barra2.dat')
tform1 = cm0[:,1]
formt = cm0[:,3]

cm1 = np.loadtxt('part_barra_color.dat')
ID0 = cm1[:,0]
ID1 = cm1[:,1]
ID2 = cm1[:,2]
ID3 = cm1[:,3]
ID4 = cm1[:,4]

cm = np.loadtxt('tform_barra2.dat')
IDs   = cm[:,0]
tform = cm[:,1]
rn_z0 = cm[:,2]
r0    = cm[:,3]

mask0 = np.isin(IDs,ID0)
mask1 = np.isin(IDs,ID1)
mask2 = np.isin(IDs,ID2)
mask3 = np.isin(IDs,ID3)
mask4 = np.isin(IDs,ID4)

r0_com = r0/formt

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
ax.plot(log10(rn_z0),log10(r0),'.', markersize=0.1, color='k')

# ax.plot(log10(rn_z0[mask0]),log10(r0[mask0]),'.', markersize=1, color='purple')
# ax.plot(log10(rn_z0[mask1]),log10(r0[mask1]),'.', markersize=1, color='r')
# ax.plot(log10(rn_z0[mask2]),log10(r0[mask2]),'.', markersize=1, color='b')
# ax.plot(log10(rn_z0[mask3]),log10(r0[mask3]),'.', markersize=1, color='g')
# ax.plot(log10(rn_z0[mask4]),log10(r0[mask4]),'.', markersize=1, color='orange')

# ax.set_xlim(-50,50)
# ax.set_ylim(-50,50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
ax.minorticks_on()
ax.tick_params( labelsize=22)#, colors='lightgray')
ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')#,colors='w')
ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on')#,colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
#ax.grid(color='lightgray',linestyle=':',which='minor')
ax.set_xlabel(r'$log(d_{z=0})\:[kpc]$', fontsize=26)#, color='lightgray')
ax.set_ylabel(r'$log(d_{tform})\:[kpc]$',fontsize=26)#, color='lightgray')
ax.axhline(y=0.4, color='r', linestyle='--')
# ax.text('d: distancia al centro', (-2.4,2.4))
fig.savefig('/home/omarioni/pyprogram_4096/dist_tform_vs distz0.png', dpi = 100)
plt.show()

# fig=plt.figure(2, figsize=(8,8))
# fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
# ax=fig.add_subplot(111)
# #     ax.plot(xn,yn,'.', markersize=0.1, color='k')
# ax.plot(tform,log10(r0),'.', markersize=1, color='k')
# # ax.set_xlim(-50,50)
# # ax.set_ylim(-50,50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
# ax.minorticks_on()
# ax.tick_params( labelsize=22, colors='lightgray')
# ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on',colors='w')
# ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on',colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
# #ax.grid(color='lightgray',linestyle=':',which='minor')
# ax.set_xlabel('Tiempo de Formacion [Gyr]', fontsize=26, color='lightgray')
# ax.set_ylabel('Distancia en tform [kpc]',fontsize=26, color='lightgray')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-5edc5d7ce4e2> in <module>()
#      56 ax.set_ylabel(r'$log(d_{tform})\:[kpc]$',fontsize=26)#, color='lightgray')
#      57 ax.axhline(y=0.4, color='r', linestyle='--')
# ---> 58 ax.text('d: distancia al centro', (-2.4,2.4))
#      59 fig.savefig('/home/omarioni/pyprogram_4096/dist_tform_vs distz0.png', dpi = 100)
#      60 plt.show()
#
# TypeError: text() takes at least 4 arguments (3 given)

# %%
import gadget_reader as gd
path = '/srv/cosmdatc/clues/B64_WM3_186592/LG/GAS_SFR/4096/SNAPS/'
sim = gd.Open(path + 'snap_496', endian='Big', gadget_type=2, verbose=False)
                             
pstr = sim.Read('POS ',4)
IDs  = sim.Read('ID  ',4)

#paso las coordenadas al centro de la galaxia y paso a coordenadas físicas
xstr = (pstr[0,:])

print xstr
# Out:
# [ 24382.44335938  24381.53320312  24396.72851562 ...,  25765.85742188
#   25140.54101562  25143.16796875]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-31ed4c421f07> in <module>()
#      11 print xstr
#      12
# ---> 13 print format(xstr, '.20f')
#
# ValueError: Unknown format code 'f' for object of type 'unicode'

# %%
type(xstr[0])
# Out:
# numpy.float32

# %%
info= np.finfo(xstr[0])

# %%
info
# Out:
# finfo(resolution=1e-06, min=-3.4028235e+38, max=3.4028235e+38, dtype=float32)
