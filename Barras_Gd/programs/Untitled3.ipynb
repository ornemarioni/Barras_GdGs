# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.arange(10)
y = np.arange(10)

plt.plot(x,y,color='#801414',lw=3)
plt.plot(-x+5,y+1,color='#FF0000',lw=3)
plt.plot(x,-y+2,color='#FF963E',lw=3)

# %%
x = np.arange(10)
y = np.arange(10)

plt.plot(x,y,color='#020076',lw=3)
plt.plot(-x+5,y+1,color='#5075FE',lw=3)
plt.plot(x,-y+2,color='#4FBFFF',lw=3)
