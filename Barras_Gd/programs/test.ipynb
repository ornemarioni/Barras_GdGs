# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#aca podemos ver el contenido que hay adentro de un file h5py

import h5py
snap = h5py.File('/home/ornela/python/ornella/outputs_1/snap_400.h5py', 'r')
def printname(name):
    print name
snap.visit(printname)
# Out:
# subhalo_000
# subhalo_000/Center
# subhalo_000/Drk
# subhalo_000/Drk/Coordinates
# subhalo_000/Drk/Ids
# subhalo_000/Drk/Masses
# subhalo_000/Drk/Velocities
# subhalo_000/Gas
# subhalo_000/Gas/Coordinates
# subhalo_000/Gas/Density
# subhalo_000/Gas/Ids
# subhalo_000/Gas/InternalEnergy
# subhalo_000/Gas/Masses
# subhalo_000/Gas/Velocities
# subhalo_000/R200
# subhalo_000/Str
# subhalo_000/Str/Coordinates
# subhalo_000/Str/FormationTime
# subhalo_000/Str/Ids
# subhalo_000/Str/Masses
# subhalo_000/Str/Metallicity
# subhalo_000/Str/Velocities
# subhalo_000/Time
# subhalo_001
# subhalo_001/Center
# subhalo_001/Drk
# subhalo_001/Drk/Coordinates
# subhalo_001/Drk/Ids
# subhalo_001/Drk/Masses
# subhalo_001/Drk/Velocities
# subhalo_001/Gas
# subhalo_001/Gas/Coordinates
# subhalo_001/Gas/Density
# subhalo_001/Gas/Ids
# subhalo_001/Gas/InternalEnergy
# subhalo_001/Gas/Masses
# subhalo_001/Gas/Velocities
# subhalo_001/R200
# subhalo_001/Str
# subhalo_001/Str/Coordinates
# subhalo_001/Str/FormationTime
# subhalo_001/Str/Ids
# subhalo_001/Str/Masses
# subhalo_001/Str/Metallicity
# subhalo_001/Str/Velocities
# subhalo_001/Time
# subhalo_003
# subhalo_003/Center
# subhalo_003/Drk
# subhalo_003/Drk/Coordinates
# subhalo_003/Drk/Ids
# subhalo_003/Drk/Masses
# subhalo_003/Drk/Velocities
# subhalo_003/Gas
# subhalo_003/Gas/Coordinates
# subhalo_003/Gas/Density
# subhalo_003/Gas/Ids
# subhalo_003/Gas/InternalEnergy
# subhalo_003/Gas/Masses
# subhalo_003/Gas/Velocities
# subhalo_003/R200
# subhalo_003/Str
# subhalo_003/Str/Coordinates
# subhalo_003/Str/FormationTime
# subhalo_003/Str/Ids
# subhalo_003/Str/Masses
# subhalo_003/Str/Metallicity
# subhalo_003/Str/Velocities
# subhalo_003/Time
# subhalo_009
# subhalo_009/Center
# subhalo_009/Drk
# subhalo_009/Drk/Coordinates
# subhalo_009/Drk/Ids
# subhalo_009/Drk/Masses
# subhalo_009/Drk/Velocities
# subhalo_009/Gas
# subhalo_009/Gas/Coordinates
# subhalo_009/Gas/Density
# subhalo_009/Gas/Ids
# subhalo_009/Gas/InternalEnergy
# subhalo_009/Gas/Masses
# subhalo_009/Gas/Velocities
# subhalo_009/R200
# subhalo_009/Str
# subhalo_009/Str/Coordinates
# subhalo_009/Str/FormationTime
# subhalo_009/Str/Ids
# subhalo_009/Str/Masses
# subhalo_009/Str/Metallicity
# subhalo_009/Str/Velocities
# subhalo_009/Time
# subhalo_013
# subhalo_013/Center
# subhalo_013/Drk
# subhalo_013/Drk/Coordinates
# subhalo_013/Drk/Ids
# subhalo_013/Drk/Masses
# subhalo_013/Drk/Velocities
# subhalo_013/Gas
# subhalo_013/Gas/Coordinates
# subhalo_013/Gas/Density
# subhalo_013/Gas/Ids
# subhalo_013/Gas/InternalEnergy
# subhalo_013/Gas/Masses
# subhalo_013/Gas/Velocities
# subhalo_013/R200
# subhalo_013/Str
# subhalo_013/Str/Coordinates
# subhalo_013/Str/FormationTime
# subhalo_013/Str/Ids
# subhalo_013/Str/Masses
# subhalo_013/Str/Metallicity
# subhalo_013/Str/Velocities
# subhalo_013/Time
# subhalo_014
# subhalo_014/Center
# subhalo_014/Drk
# subhalo_014/Drk/Coordinates
# subhalo_014/Drk/Ids
# subhalo_014/Drk/Masses
# subhalo_014/Drk/Velocities
# subhalo_014/Gas
# subhalo_014/Gas/Coordinates
# subhalo_014/Gas/Density
# subhalo_014/Gas/Ids
# subhalo_014/Gas/InternalEnergy
# subhalo_014/Gas/Masses
# subhalo_014/Gas/Velocities
# subhalo_014/R200
# subhalo_014/Str
# subhalo_014/Str/Coordinates
# subhalo_014/Str/FormationTime
# subhalo_014/Str/Ids
# subhalo_014/Str/Masses
# subhalo_014/Str/Metallicity
# subhalo_014/Str/Velocities
# subhalo_014/Time
# subhalo_018
# subhalo_018/Center
# subhalo_018/Drk
# subhalo_018/Drk/Coordinates
# subhalo_018/Drk/Ids
# subhalo_018/Drk/Masses
# subhalo_018/Drk/Velocities
# subhalo_018/Gas
# subhalo_018/Gas/Coordinates
# subhalo_018/Gas/Density
# subhalo_018/Gas/Ids
# subhalo_018/Gas/InternalEnergy
# subhalo_018/Gas/Masses
# subhalo_018/Gas/Velocities
# subhalo_018/R200
# subhalo_018/Str
# subhalo_018/Str/Coordinates
# subhalo_018/Str/FormationTime
# subhalo_018/Str/Ids
# subhalo_018/Str/Masses
# subhalo_018/Str/Metallicity
# subhalo_018/Str/Velocities
# subhalo_018/Time
# subhalo_019
# subhalo_019/Center
# subhalo_019/Drk
# subhalo_019/Drk/Coordinates
# subhalo_019/Drk/Ids
# subhalo_019/Drk/Masses
# subhalo_019/Drk/Velocities
# subhalo_019/Gas
# subhalo_019/Gas/Coordinates
# subhalo_019/Gas/Density
# subhalo_019/Gas/Ids
# subhalo_019/Gas/InternalEnergy
# subhalo_019/Gas/Masses
# subhalo_019/Gas/Velocities
# subhalo_019/R200
# subhalo_019/Str
# subhalo_019/Str/Coordinates
# subhalo_019/Str/FormationTime
# subhalo_019/Str/Ids
# subhalo_019/Str/Masses
# subhalo_019/Str/Metallicity
# subhalo_019/Str/Velocities
# subhalo_019/Time
# subhalo_020
# subhalo_020/Center
# subhalo_020/Drk
# subhalo_020/Drk/Coordinates
# subhalo_020/Drk/Ids
# subhalo_020/Drk/Masses
# subhalo_020/Drk/Velocities
# subhalo_020/Gas
# subhalo_020/Gas/Coordinates
# subhalo_020/Gas/Density
# subhalo_020/Gas/Ids
# subhalo_020/Gas/InternalEnergy
# subhalo_020/Gas/Masses
# subhalo_020/Gas/Velocities
# subhalo_020/R200
# subhalo_020/Str
# subhalo_020/Str/Coordinates
# subhalo_020/Str/FormationTime
# subhalo_020/Str/Ids
# subhalo_020/Str/Masses
# subhalo_020/Str/Metallicity
# subhalo_020/Str/Velocities
# subhalo_020/Time
# subhalo_021
# subhalo_021/Center
# subhalo_021/Drk
# subhalo_021/Drk/Coordinates
# subhalo_021/Drk/Ids
# subhalo_021/Drk/Masses
# subhalo_021/Drk/Velocities
# subhalo_021/Gas
# subhalo_021/Gas/Coordinates
# subhalo_021/Gas/Density
# subhalo_021/Gas/Ids
# subhalo_021/Gas/InternalEnergy
# subhalo_021/Gas/Masses
# subhalo_021/Gas/Velocities
# subhalo_021/R200
# subhalo_021/Str
# subhalo_021/Str/Coordinates
# subhalo_021/Str/FormationTime
# subhalo_021/Str/Ids
# subhalo_021/Str/Masses
# subhalo_021/Str/Metallicity
# subhalo_021/Str/Velocities
# subhalo_021/Time
