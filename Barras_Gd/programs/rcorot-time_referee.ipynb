# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/correcciones/'

GADGET = np.loadtxt(path+'rcorot_time_GD_3.dat')
time_M31gd  = GADGET[:,0]
rcorot11_M31gd = GADGET[:,1]
# rcorot21_M31gd = GADGET[:,2]
rcorot31_M31gd = GADGET[:,3]
# rcorot41_M31gd = GADGET[:,4]
rcorot51_M31gd = GADGET[:,5]
rcorot61_M31gd = GADGET[:,6]
rcorot12_M31gd = GADGET[:,7]
# rcorot22_M31gd = GADGET[:,8]
rcorot32_M31gd = GADGET[:,9]
# rcorot42_M31gd = GADGET[:,10]
rcorot52_M31gd = GADGET[:,11]
rcorot62_M31gd = GADGET[:,12]
rcorot13_M31gd = GADGET[:,13]
# rcorot23_M31gd = GADGET[:,14]
rcorot33_M31gd = GADGET[:,15]
# rcorot43_M31gd = GADGET[:,16]
rcorot53_M31gd = GADGET[:,17]
rcorot63_M31gd = GADGET[:,18]

# %%
import numpy as np
data = np.loadtxt('../_data/correcciones/lbar_time_GD3.dat')
# time_M31gd  = data[:,0]
lbar1_M31gd = data[:,1]
# lbar2_M31gd = data[:,2]
lbar3_M31gd = data[:,3]
# lbar4_M31gd = data[:,4]
lbar5_M31gd = data[:,5]
lbar6_M31gd = data[:,6]

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_M31gd,rcorot11_M31gd, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_M31gd,rcorot12_M31gd, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_M31gd,rcorot13_M31gd, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,4)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
# ax[0,1].plot(time_M31gd,rcorot21_M31gd, color='g', lw=1, label='$\Omega_{bar}$ disco')
# ax[0,1].plot(time_M31gd,rcorot22_M31gd, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
# ax[0,1].plot(time_M31gd,rcorot23_M31gd, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_M31gd,rcorot51_M31gd, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gd,rcorot52_M31gd, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gd,rcorot53_M31gd, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,4)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_M31gd,rcorot31_M31gd, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_M31gd,rcorot32_M31gd, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_M31gd,rcorot33_M31gd, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,4)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
# ax[1,1].plot(time_M31gd,rcorot41_M31gd, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
# ax[1,1].plot(time_M31gd,rcorot42_M31gd, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
# ax[1,1].plot(time_M31gd,rcorot43_M31gd, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_M31gd,rcorot61_M31gd, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gd,rcorot62_M31gd, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gd,rcorot63_M31gd, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,4)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_M31gd,rcorot11_M31gd/lbar1_M31gd, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_M31gd,rcorot12_M31gd/lbar1_M31gd, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_M31gd,rcorot13_M31gd/lbar1_M31gd, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,2.5)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,1].plot(time_M31gd,rcorot21_M31gd/lbar2_M31gd, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gd,rcorot22_M31gd/lbar2_M31gd, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gd,rcorot23_M31gd/lbar2_M31gd, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_M31gd,rcorot51_M31gd/lbar5_M31gd, color='m', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gd,rcorot52_M31gd/lbar5_M31gd, color='m', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gd,rcorot53_M31gd/lbar5_M31gd, color='m', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,2.5)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_M31gd,rcorot31_M31gd/lbar3_M31gd, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_M31gd,rcorot32_M31gd/lbar3_M31gd, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_M31gd,rcorot33_M31gd/lbar3_M31gd, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,2.5)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,1].plot(time_M31gd,rcorot41_M31gd/lbar4_M31gd, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gd,rcorot42_M31gd/lbar4_M31gd, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gd,rcorot43_M31gd/lbar4_M31gd, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_M31gd,rcorot61_M31gd/lbar6_M31gd, color='c', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gd,rcorot62_M31gd/lbar6_M31gd, color='c', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gd,rcorot63_M31gd/lbar6_M31gd, color='c', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,2.5)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')

# %%
import numpy as np
data = np.loadtxt('../_data/correcciones/lbar_time_GS2_001.dat')
time_M31gs  = data[:,0]
lbar1_M31gs = data[:,1]
lbar2_M31gs = data[:,2]
lbar3_M31gs = data[:,3]
lbar4_M31gs = data[:,4]
lbar5_M31gs = data[:,5]
lbar6_M31gs = data[:,6]

data = np.loadtxt('../_data/correcciones/lbar_time_GS2_002.dat')
time_MWgs  = data[:,0]
lbar1_MWgs = data[:,1]
lbar2_MWgs = data[:,2]
lbar3_MWgs = data[:,3]
lbar4_MWgs = data[:,4]
lbar5_MWgs = data[:,5]
lbar6_MWgs = data[:,6]

# %%
path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/correcciones/'
GASOLINE1 = np.loadtxt(path+'rcorot_time_GS_total_001.dat')
# time    = GASOLINE1[:,0]
rcorot11_M31gs = GASOLINE1[:,1]
rcorot21_M31gs = GASOLINE1[:,2]
rcorot31_M31gs = GASOLINE1[:,3]
rcorot41_M31gs = GASOLINE1[:,4]
rcorot51_M31gs = GASOLINE1[:,5]
rcorot61_M31gs = GASOLINE1[:,6]
rcorot12_M31gs = GASOLINE1[:,7]
rcorot22_M31gs = GASOLINE1[:,8]
rcorot32_M31gs = GASOLINE1[:,9]
rcorot42_M31gs = GASOLINE1[:,10]
rcorot52_M31gs = GASOLINE1[:,11]
rcorot62_M31gs = GASOLINE1[:,12]
rcorot13_M31gs = GASOLINE1[:,13]
rcorot23_M31gs = GASOLINE1[:,14]
rcorot33_M31gs = GASOLINE1[:,15]
rcorot43_M31gs = GASOLINE1[:,16]
rcorot53_M31gs = GASOLINE1[:,17]
rcorot63_M31gs = GASOLINE1[:,18]

GASOLINE2 = np.loadtxt(path+'rcorot_time_GS_total_002.dat')
# time    = GASOLINE2[:,0]
rcorot11_MWgs = GASOLINE2[:,1]
rcorot21_MWgs = GASOLINE2[:,2]
rcorot31_MWgs = GASOLINE2[:,3]
rcorot41_MWgs = GASOLINE2[:,4]
rcorot51_MWgs = GASOLINE2[:,5]
rcorot61_MWgs = GASOLINE2[:,6]
rcorot12_MWgs = GASOLINE2[:,7]
rcorot22_MWgs = GASOLINE2[:,8]
rcorot32_MWgs = GASOLINE2[:,9]
rcorot42_MWgs = GASOLINE2[:,10]
rcorot52_MWgs = GASOLINE2[:,11]
rcorot62_MWgs = GASOLINE2[:,12]
rcorot13_MWgs = GASOLINE2[:,13]
rcorot23_MWgs = GASOLINE2[:,14]
rcorot33_MWgs = GASOLINE2[:,15]
rcorot43_MWgs = GASOLINE2[:,16]
rcorot53_MWgs = GASOLINE2[:,17]
rcorot63_MWgs = GASOLINE2[:,18]

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_M31gs,rcorot11_M31gs, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_M31gs,rcorot12_M31gs, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_M31gs,rcorot13_M31gs, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,4)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,1].plot(time_M31gs,rcorot21_M31gs, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gs,rcorot22_M31gs, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gs,rcorot23_M31gs, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_M31gs,rcorot51_M31gs, color='m', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gs,rcorot52_M31gs, color='m', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gs,rcorot53_M31gs, color='m', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,4)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_M31gs,rcorot31_M31gs, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_M31gs,rcorot32_M31gs, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_M31gs,rcorot33_M31gs, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,4)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,1].plot(time_M31gs,rcorot41_M31gs, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gs,rcorot42_M31gs, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gs,rcorot43_M31gs, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_M31gs,rcorot61_M31gs, color='c', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gs,rcorot62_M31gs, color='c', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gs,rcorot63_M31gs, color='c', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,4)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_M31gs,rcorot11_M31gs/lbar1_M31gs, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_M31gs,rcorot12_M31gs/lbar1_M31gs, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_M31gs,rcorot13_M31gs/lbar1_M31gs, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,2.5)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,1].plot(time_M31gs,rcorot21_M31gs/lbar2_M31gs, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gs,rcorot22_M31gs/lbar2_M31gs, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gs,rcorot23_M31gs/lbar2_M31gs, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_M31gs,rcorot51_M31gs/lbar5_M31gs, color='m', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_M31gs,rcorot52_M31gs/lbar5_M31gs, color='m', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_M31gs,rcorot53_M31gs/lbar5_M31gs, color='m', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,2.5)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_M31gs,rcorot31_M31gs/lbar3_M31gs, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_M31gs,rcorot32_M31gs/lbar3_M31gs, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_M31gs,rcorot33_M31gs/lbar3_M31gs, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,2.5)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,1].plot(time_M31gs,rcorot41_M31gs/lbar4_M31gs, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gs,rcorot42_M31gs/lbar4_M31gs, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gs,rcorot43_M31gs/lbar4_M31gs, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_M31gs,rcorot61_M31gs/lbar6_M31gs, color='c', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_M31gs,rcorot62_M31gs/lbar6_M31gs, color='c', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_M31gs,rcorot63_M31gs/lbar6_M31gs, color='c', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,2.5)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_MWgs,rcorot11_MWgs, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_MWgs,rcorot12_MWgs, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_MWgs,rcorot13_MWgs, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,10)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,1].plot(time_MWgs,rcorot21_MWgs, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_MWgs,rcorot22_MWgs, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_MWgs,rcorot23_MWgs, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_MWgs,rcorot51_MWgs, color='m', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_MWgs,rcorot52_MWgs, color='m', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_MWgs,rcorot53_MWgs, color='m', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,10)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_MWgs,rcorot31_MWgs, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_MWgs,rcorot32_MWgs, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_MWgs,rcorot33_MWgs, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}$ [kpc]',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,10)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,1].plot(time_MWgs,rcorot41_MWgs, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_MWgs,rcorot42_MWgs, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_MWgs,rcorot43_MWgs, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_MWgs,rcorot61_MWgs, color='c', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_MWgs,rcorot62_MWgs, color='c', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_MWgs,rcorot63_MWgs, color='c', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,10)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10,10), sharex=True)
#                        gridspec_kw = {'height_ratios':[2,5]})
fig.subplots_adjust(bottom=0.06, left =0.1, right = 0.93, top = 0.96, wspace=0.2, hspace= 0.1)

# ax[0,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,0].plot(time_MWgs,rcorot11_MWgs/lbar1_MWgs, color='r', lw=1, label='$\Omega_{bar}$ disco')
ax[0,0].plot(time_MWgs,rcorot12_MWgs/lbar1_MWgs, color='r', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,0].plot(time_MWgs,rcorot13_MWgs/lbar1_MWgs, color='r', lw=1, ls=':', label='$\Omega_{bar}$ elipsoide')
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=15)
ax[0,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[0,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
# ax[0,0].set_xlabel('time [Gyr]',fontsize=15)
ax[0,0].set_ylim(0,5)
ax[0,0].set_title('lbar1 - 0.15', fontsize=15)
ax[0,0].legend(fontsize=15,frameon=False)

# ax[0,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[0,1].plot(time_MWgs,rcorot21_MWgs/lbar2_MWgs, color='g', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_MWgs,rcorot22_MWgs/lbar2_MWgs, color='g', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_MWgs,rcorot23_MWgs/lbar2_MWgs, color='g', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].plot(time_MWgs,rcorot51_MWgs/lbar5_MWgs, color='m', lw=1, label='$\Omega_{bar}$ disco')
ax[0,1].plot(time_MWgs,rcorot52_MWgs/lbar5_MWgs, color='m', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[0,1].plot(time_MWgs,rcorot53_MWgs/lbar5_MWgs, color='m', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=15)
ax[0,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[0,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[0,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
# ax[0,1].set_xlabel('time [Gyr]',fontsize=15)
ax[0,1].set_ylim(0,5)
ax[0,1].set_title('lbar2 - phi', fontsize=15)
# ax[0,1].legend(fontsize=15,frameon=False)

# ax[1,0].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,0].plot(time_MWgs,rcorot31_MWgs/lbar3_MWgs, color='b', lw=1, label='$\Omega_{bar}$ disco')
ax[1,0].plot(time_MWgs,rcorot32_MWgs/lbar3_MWgs, color='b', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,0].plot(time_MWgs,rcorot33_MWgs/lbar3_MWgs, color='b', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=15)
ax[1,0].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,0].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
ax[1,0].set_ylabel('$R_{corot}/l_{bar}$',fontsize=15)
ax[1,0].set_xlabel('time [Gyr]',fontsize=15)
ax[1,0].set_ylim(0,5)
ax[1,0].set_title('lbar3 - 0.25*A2max', fontsize=15)
# ax[1,0].legend(fontsize=15,frameon=False)

# ax[1,1].plot(tt, veloc_ang*2*np.pi/360.*1.0219051207939474,'k')
ax[1,1].plot(time_MWgs,rcorot41_MWgs/lbar4_MWgs, color='darkorange', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_MWgs,rcorot42_MWgs/lbar4_MWgs, color='darkorange', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_MWgs,rcorot43_MWgs/lbar4_MWgs, color='darkorange', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].plot(time_MWgs,rcorot61_MWgs/lbar6_MWgs, color='c', lw=1, label='$\Omega_{bar}$ disco')
ax[1,1].plot(time_MWgs,rcorot62_MWgs/lbar6_MWgs, color='c', lw=1, ls='--', label='$\Omega_{bar}$ puntas')
ax[1,1].plot(time_MWgs,rcorot63_MWgs/lbar6_MWgs, color='c', lw=1, ls=':',label='$\Omega_{bar}$ elipsoide')
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=15)
ax[1,1].tick_params('both', length=7, width=1.2,which='minor', direction='in', right=True,top=False)
ax[1,1].tick_params('both', length=10, width=1.2,which='major', direction='in', right=True,top=False)
# ax[1,1].set_ylabel('$\Omega_{bar}$ [km/s/kpc]',fontsize=15)
ax[1,1].set_xlabel('time [Gyr]',fontsize=15)
ax[1,1].set_ylim(0,5)
ax[1,1].set_title('lbar4 - perfiles', fontsize=15)
# ax[1,1].legend(fontsize=15,frameon=False)
# Out:
# Text(0.5,1,'lbar4 - perfiles')
