# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Particulas de las galaxias en los tiempos de formación

# %% [markdown]
# #### Gadget

# %%
path2 = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/'

M31gd = np.loadtxt(path2 + 'M31_tform_particles.dat')
ID_M31gd = M31gd[:,0]
r_M31gd  = M31gd[:,1]
tf_M31gd = M31gd[:,2]

M31gd = np.loadtxt(path2 + 'M31_part_barra.dat')
Ids_M31gd  = M31gd[:,0]

mask_M31gd = np.isin(ID_M31gd, Ids_M31gd)

#-------------------------------------------------------------------

MWgd = np.loadtxt(path2 + 'MW_tform_particles.dat')
ID_MWgd = MWgd[:,0]
r_MWgd  = MWgd[:,1]
tf_MWgd = MWgd[:,2]

#-----------------------------------------------------------------
M33gd = np.loadtxt(path2 + 'M33_tform_particles.dat')
ID_M33gd = M33gd[:,0]
r_M33gd  = M33gd[:,1]
tf_M33gd = M33gd[:,2]

# %% [markdown]
# #### Gasoline

# %%
path2 = '/home/omarioni/Barras_GdGs/Barras_Gs/_data/'

M31gs = np.loadtxt(path2 + 'M31_tform_particles.dat') 
ID_M31gs = M31gs[:,0]
r_M31gs  = M31gs[:,1]
tf_M31gs = M31gs[:,2]

M31gs = np.loadtxt(path2 + 'M31_part_barra.dat')
Ids_M31gs  = M31gs[:,0]

mask_M31gs = np.isin(ID_M31gs, Ids_M31gs)

#-------------------------------------------------------------------

MWgs = np.loadtxt(path2 + 'MW_tform_particles.dat')
ID_MWgs = MWgs[:,0]
r_MWgs  = MWgs[:,1]
tf_MWgs = MWgs[:,2]

MWgs = np.loadtxt(path2 + 'MW_part_barra.dat')
Ids_MWgs = MWgs[:,0]

mask_MWgs = np.isin(ID_MWgs, Ids_MWgs)

#-----------------------------------------------------------------
M33gs = np.loadtxt(path2 + 'M33_tform_particles.dat')
ID_M33gs = M33gs[:,0]
r_M33gs  = M33gs[:,1]
tf_M33gs = M33gs[:,2]

# %% [markdown]
# ### Porcentajes

# %%
#In situ --------------------------------------------
M31gd_insitu = 1.*len(ID_M31gd[np.where(r_M31gd <= 15)])/len(ID_M31gd)
print M31gd_insitu

MWgd_insitu = 1.*len(ID_MWgd[np.where(r_MWgd <= 15)])/len(ID_MWgd)
print MWgd_insitu

M33gd_insitu = 1.*len(ID_M33gd[np.where(r_M33gd <= 15)])/len(ID_M33gd)
print M33gd_insitu

print '----------------------------'
M31gs_insitu = 1.*len(ID_M31gs[np.where(r_M31gs <= 15)])/len(ID_M31gs)
print M31gs_insitu

MWgs_insitu = 1.*len(ID_MWgs[np.where(r_MWgs <= 15)])/len(ID_MWgs)
print MWgs_insitu

M33gs_insitu = 1.*len(ID_M33gs[np.where(r_M33gs <= 15)])/len(ID_M33gs)
print M33gs_insitu


print '----------------------------'

#Barras 
#In situ --------------------------------------------
M31gd_b = 1.*len(ID_M31gd[mask_M31gd][np.where(r_M31gd[mask_M31gd] <= 15)])/len(ID_M31gd[mask_M31gd])
print M31gd_b
print M31gd_insitu*M31gd_b
print '...'

M31gs_b = 1.*len(ID_M31gs[mask_M31gs][np.where(r_M31gs[mask_M31gs] <= 15)])/len(ID_M31gs[mask_M31gs])
print M31gs_b
print M31gs_insitu*M31gs_b
print '...'


MWgs_b = 1.*len(ID_MWgs[mask_MWgs][np.where(r_MWgs[mask_MWgs] <= 15)])/len(ID_MWgs[mask_MWgs])
print MWgs_b
print MWgs_insitu*MWgs_b
print '...'
# Out:
# 0.720032506191
# 0.470137325825
# 0.809649888101
# ----------------------------
# 0.781230521832
# 0.562543613183
# 0.859291418867
# ----------------------------
# 0.948099834395
# 0.682662699879
# ...
# 0.960891195385
# 0.750677529995
# ...
# 0.938201374683
# 0.527779191207
# ...

# %%
len(ID_M31gd[mask_M31gd])*1./len(ID_M31gd)
# Out:
# 0.4223744912418904

# %%
len(ID_M31gs[mask_M31gs])*1./len(ID_M31gs)
# Out:
# 0.4271554731575065

# %%
len(ID_MWgs[mask_MWgs])*1./len(ID_MWgs)
# Out:
# 0.3202838427637292

# %%
path = '/home/omarioni/'
M31_gd = np.loadtxt(path + 'Barras_GdGs/Barras_Gd/_data/M31_lbarvstime2.dat')
time0_M31gd = M31_gd[:,0][-1]
print time0_M31gd
#------------------------------------------------------------------------------------------
M31_gs = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/M31_lbarvstime.dat')
time0_M31gs = M31_gs[:,0][-1]
print time0_M31gs

#------------------------------------------------------------------------------------------
MW_gs = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/MW_lbarvstime.dat')
time0_MWgs = MW_gs[:,0][-1]
print time0_MWgs
# Out:
# 8.623489
# 8.159224
# 10.730151

# %%
# from __future__ import unicode_literals

# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['text.latex.unicode'] = True

fig, ax = plt.subplots(nrows=8, ncols=5, figsize=(18, 26),#, sharey=True, sharex=True
                       gridspec_kw = {'height_ratios':[1,3,0.3,1,3,0.3,1,3], 'width_ratios':[3,1,0.3,3,1]})
fig.subplots_adjust(bottom=0.06, left =0.12, right = 0.97, top = 0.97, wspace=0., hspace= 0)


ax[1,0].plot(tf_M31gd ,np.log10(r_M31gd),'.', markersize=0.1, color='k')
ax[1,0].plot(tf_M31gd[mask_M31gd] ,np.log10(r_M31gd[mask_M31gd]),'.', markersize=0.1, color='r')
ax[1,0].set_ylabel('$\mathrm{log(d/kpc)}$', fontsize=42)
ax[1,0].set_xticks([0,2,4,6,8,10,12])
ax[1,0].set_xticklabels([])
ax[1,0].set_yticks([-2,-1,0,1,2])
ax[1,0].set_ylim(-2,2.8)
ax[1,0].set_xlim(0,14)
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=42)
ax[1,0].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[1,0].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[1,0].text(12.2, 2.4, '$\mathrm{A}$', fontsize=42, color='k', ha='left', va='center')


ax[0,0].hist(tf_M31gd, bins=30, histtype='step',lw=2, color='k' )
ax[0,0].hist(tf_M31gd[mask_M31gd], bins=30, histtype='step', color='r', lw=2)
ax[0,0].set_xlim(0,14)
ax[0,0].set_ylim(0,90000)
ax[0,0].set_xticklabels([])
ax[0,0].set_yticks(range(0,90000,10000))
ax[0,0].set_yticklabels([])
ax[0,0].tick_params( labelsize=42)
# ax[0,0].minorticks_on()
# ax[0,0].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[0,0].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[0,0].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')
ax[0,0].set_title('GADGET2', loc='center', fontsize=42)
ax[0,0].arrow(x=time0_M31gd,y=90000,dx=0,dy=-40000,color='#801414', lw=3.5,
         head_length=8000,head_width=0.4,length_includes_head=True)
ax[0,0].text(time0_M31gd+0.5, 85000, '$\mathrm{t_\mathrm{bar}}$', fontsize=42, color='black', ha='left', va='top')



ax[1,1].hist(np.log10(r_M31gd),  bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[1,1].hist(np.log10(r_M31gd[mask_M31gd]),color='r', bins=30, histtype='step',lw=2, orientation='horizontal')
ax[1,1].set_ylim(-2,2.8)
ax[1,1].set_xlim(0,90000)
ax[1,1].set_yticklabels([])
ax[1,1].set_xticks(range(0,90000,10000))
ax[1,1].set_xticklabels([])
ax[1,1].tick_params( labelsize=42)
# ax[1,1].minorticks_on()
# ax[1,1].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[1,1].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[1,1].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[0,1].axis('off')
ax[0,2].axis('off')
ax[1,2].axis('off')

#-----------------------------------------------------
M1, = np.where(r_M31gs>1e-2)
M2, = np.where(r_M31gs[mask_M31gs]>1e-2)

ax[1,3].plot(tf_M31gs[M1] ,np.log10(r_M31gs[M1]),'.', markersize=0.1, color='k')
ax[1,3].plot(tf_M31gs[mask_M31gs][M2] ,np.log10(r_M31gs[mask_M31gs][M2]),'.', markersize=0.1, color='r')
ax[1,3].set_xticks([0,2,4,6,8,10,12,14])
ax[1,3].set_xticklabels([])
ax[1,3].set_yticks([-2,-1,0,1,2])
ax[1,3].set_yticklabels([])
ax[1,3].set_ylim(-2,2.8)
ax[1,3].set_xlim(0,14)
ax[1,3].minorticks_on()
ax[1,3].tick_params( labelsize=42)
ax[1,3].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[1,3].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[1,3].text(12.2, 2.4, '$\mathrm{A}$', fontsize=42, color='k', ha='left', va='center')


ax[0,3].hist(tf_M31gs[M1], bins=30, histtype='step',lw=2, color='k' )
ax[0,3].hist(tf_M31gs[mask_M31gs][M2], bins=30, histtype='step', color='r', lw=2)
ax[0,3].set_xlim(0,14)
ax[0,3].set_ylim(0,90000)
ax[0,3].set_xticklabels([])
ax[0,3].set_yticks(range(0,90000,10000))
ax[0,3].set_yticklabels([])
ax[0,3].tick_params( labelsize=42)
# ax[0,3].minorticks_on()
# ax[0,3].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[0,3].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[0,3].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')
ax[0,3].set_title('GASOLINE', loc='center', fontsize=42)
ax[0,3].arrow(x=time0_M31gs,y=90000,dx=0,dy=-40000,color='#FF0000', lw=3.5,
         head_length=8000,head_width=0.4,length_includes_head=True)

ax[1,4].hist(np.log10(r_M31gs[M1]), bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[1,4].hist(np.log10(r_M31gs[mask_M31gs][M2]),color='r', bins=30, histtype='step',lw=2, orientation='horizontal')
ax[1,4].set_ylim(-2,2.8)
ax[1,4].set_xlim(0,90000)
ax[1,4].set_yticklabels([])
ax[1,4].set_xticks(range(0,90000,10000))
ax[1,4].set_xticklabels([])
ax[1,4].tick_params( labelsize=42)
# ax[1,4].minorticks_on()
# ax[1,4].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[1,4].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[1,4].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[0,4].axis('off')
# # #---------------------------------------------------------
ax[2,0].axis('off')
ax[2,1].axis('off')
ax[2,2].axis('off')
ax[2,3].axis('off')
ax[2,4].axis('off')

ax[4,0].plot(tf_MWgd ,np.log10(r_MWgd),'.', markersize=0.1, color='k')
ax[4,0].set_ylabel('$\mathrm{log(d/kpc)}$', fontsize=42)
ax[4,0].set_xticks([0,2,4,6,8,10,12])
ax[4,0].set_xticklabels([])
ax[4,0].set_yticks([-2,-1,0,1,2])
ax[4,0].set_ylim(-2,2.8)
ax[4,0].set_xlim(0,14)
ax[4,0].minorticks_on()
ax[4,0].tick_params( labelsize=42)
ax[4,0].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[4,0].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[4,0].text(12.2, 2.4, '$\mathrm{B}$', fontsize=42, color='k', ha='left', va='center')

ax[3,0].hist(tf_MWgd, bins=30, histtype='step', lw=2, color='k' )
ax[3,0].set_xlim(0,14)
ax[3,0].set_ylim(0,90000)
ax[3,0].set_xticklabels([])
ax[3,0].set_yticks(range(0,90000,10000))
ax[3,0].set_yticklabels([])
ax[3,0].tick_params( labelsize=42)
# ax[3,0].minorticks_on()
# ax[3,0].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[3,0].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[3,0].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')

ax[4,1].hist(np.log10(r_MWgd), bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[4,1].set_ylim(-2,2.8)
ax[4,1].set_xlim(0,90000)
ax[4,1].set_yticklabels([])
ax[4,1].set_xticks(range(0,90000,10000))
ax[4,1].set_xticklabels([])
ax[4,1].tick_params( labelsize=42)
# ax[4,1].minorticks_on()
# ax[4,1].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[4,1].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[4,1].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[3,1].axis('off')
ax[3,2].axis('off')
ax[4,2].axis('off')

#---------------------------------------------------------
M1, = np.where(r_MWgs>1e-2)
M2, = np.where(r_MWgs[mask_MWgs]>1e-2)

ax[4,3].plot(tf_MWgs[M1] ,np.log10(r_MWgs[M1]),'.', markersize=0.1, color='k')
ax[4,3].plot(tf_MWgs[mask_MWgs][M2] ,np.log10(r_MWgs[mask_MWgs][M2]),'.', markersize=0.1, color='r')
ax[4,3].set_xticks([0,2,4,6,8,10,12])
ax[4,3].set_xticklabels([])
ax[4,3].set_yticks([-2,-1,0,1,2])
ax[4,3].set_yticklabels([])
ax[4,3].set_ylim(-2,2.8)
ax[4,3].set_xlim(0,14)
ax[4,3].minorticks_on()
ax[4,3].tick_params( labelsize=42)
ax[4,3].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[4,3].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[4,3].text(12.2, 2.4, '$\mathrm{B}$', fontsize=42, color='k', ha='left', va='center')

ax[3,3].hist(tf_MWgs[M1], bins=30, histtype='step',lw=2, color='k' )
ax[3,3].hist(tf_MWgs[mask_MWgs][M2], bins=30, histtype='step', color='r', lw=2)
ax[3,3].set_xlim(0,14)
ax[3,3].set_ylim(0,90000)
ax[3,3].set_xticklabels([])
ax[3,3].set_yticks(range(0,90000,10000))
ax[3,3].set_yticklabels([])
ax[3,3].tick_params( labelsize=42)
# ax[3,3].minorticks_on()
# ax[3,3].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[3,3].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[3,3].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')
ax[3,3].arrow(x=time0_MWgs,y=90000,dx=0,dy=-40000,color='#FF963E', lw=3.5,
         head_length=8000,head_width=0.4,length_includes_head=True)

ax[4,4].hist(np.log10(r_MWgs[M1]), bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[4,4].hist(np.log10(r_MWgs[mask_MWgs][M2]),color='r', bins=30, histtype='step',lw=2, orientation='horizontal')
ax[4,4].set_ylim(-2,2.8)
ax[4,4].set_xlim(0,90000)
ax[4,4].set_yticklabels([])
ax[4,4].set_xticks(range(0,90000,10000))
ax[4,4].set_xticklabels([])
ax[4,4].tick_params( labelsize=42)
# ax[4,4].minorticks_on()
# ax[4,4].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[4,4].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[4,4].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[3,4].axis('off')

# # #---------------------------------------------------------------------------------------
ax[5,0].axis('off')
ax[5,1].axis('off')
ax[5,2].axis('off')
ax[5,3].axis('off')
ax[5,4].axis('off')

ax[7,0].plot(tf_M33gd ,np.log10(r_M33gd),'.', markersize=0.1, color='k')
ax[7,0].set_xticks([0,2,4,6,8,10,12,14])
ax[7,0].set_xlabel('$\mathrm{t_{form}\:[Gyr]}$', fontsize=42)
ax[7,0].set_ylabel('$\mathrm{log(d/kpc)}$', fontsize=42)
ax[7,0].set_yticks([-2,-1,0,1,2])
ax[7,0].set_ylim(-2,2.8)
ax[7,0].set_xlim(0,14)
ax[7,0].minorticks_on()
ax[7,0].tick_params( labelsize=42)
ax[7,0].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[7,0].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[7,0].text(12.2, 2.4, '$\mathrm{C}$', fontsize=42, color='k', ha='left', va='center')

ax[6,0].hist(tf_M33gd, bins=30, histtype='step',lw=2, color='k' )
ax[6,0].set_xlim(0,14)
ax[6,0].set_ylim(0,90000)
ax[6,0].set_xticklabels([])
ax[6,0].set_yticks(range(0,90000,10000))
ax[6,0].set_yticklabels([])
ax[6,0].tick_params( labelsize=42)
# ax[6,0].minorticks_on()
# ax[6,0].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[6,0].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[6,0].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')

ax[7,1].hist(np.log10(r_M33gd), bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[7,1].set_ylim(-2,2.8)
ax[7,1].set_xlim(0,90000)
ax[7,1].set_yticklabels([])
ax[7,1].set_xticks(range(0,90000,10000))
ax[7,1].set_xticklabels([])
ax[7,1].tick_params( labelsize=42)
# ax[7,1].minorticks_on()
# ax[7,1].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[7,1].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[7,1].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[7,2].axis('off')
ax[6,1].axis('off')
ax[6,2].axis('off')

# # #---------------------------------------------------------------------------------------
M1, = np.where(r_M33gs>1e-2)

ax[7,3].plot(tf_M33gs[M1] ,np.log10(r_M33gs[M1]),'.', markersize=0.1, color='k')
ax[7,3].set_xticks([0,2,4,6,8,10,12,14])
ax[7,3].set_xlabel('$\mathrm{t_{form}\:[Gyr]}$', fontsize=42)
ax[7,3].set_yticks([-2,-1,0,1,2])
ax[7,3].set_yticklabels([])
ax[7,3].set_ylim(-2,2.8)
ax[7,3].set_xlim(0,14)
ax[7,3].minorticks_on()
ax[7,3].tick_params( labelsize=42)
ax[7,3].tick_params('both', length=10, width=2, which='minor', direction='in', right='true',top='true')
ax[7,3].tick_params('both', length=15, width=2, which='major', direction='in', right='true',top='true')
ax[7,3].text(12.2, 2.4, '$\mathrm{C}$', fontsize=42, color='k', ha='left', va='center')
# ax[7,3].axhline(y=np.log10(15),ls='--', color='gray', lw=2)


ax[6,3].hist(tf_M33gs[M1], bins=30, histtype='step',lw=2, color='k' )
ax[6,3].set_xlim(0,14)
ax[6,3].set_ylim(0,90000)
ax[6,3].set_xticklabels([])
ax[6,3].set_yticks(range(0,90000,10000))
ax[6,3].set_yticklabels([])
ax[6,3].tick_params( labelsize=42)
# ax[6,3].minorticks_on()
# ax[6,3].yaxis.set_minor_locator(MultipleLocator(10000))
# ax[6,3].tick_params('y', length=8,  width=1.5, which='minor', direction='in', right='False',top='False')
ax[6,3].tick_params('y', length=15, width=2, which='major', direction='in', right='False',top='False')

ax[7,4].hist(np.log10(r_M33gs[M1]), bins=30, histtype='step', lw=2, color='k', orientation='horizontal')
ax[7,4].set_ylim(-2,2.8)
ax[7,4].set_xlim(0,90000)
ax[7,4].set_yticklabels([])
ax[7,4].set_xticks(range(0,90000,10000))
ax[7,4].set_xticklabels([])
ax[7,4].tick_params( labelsize=42)
# ax[7,4].minorticks_on()
# ax[7,4].xaxis.set_minor_locator(MultipleLocator(10000))
# ax[7,4].tick_params('x', length=8,  width=1.5, which='minor', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')
ax[7,4].tick_params('x', length=15, width=2, which='major', direction='in', right='False',top='True', bottom='False',labeltop='True', labelbottom='False')

ax[6,4].axis('off')
# # #---------------------------------------------------------------------------------------

# fig.savefig('/home/ornela/overleaf/13216980csjxswjndpmj/tform_bar.png', dpi = 100, xxbox_inches='tight')
fig.savefig('/home/omarioni/Barras_GdGs/Barras_Gd/_imagenes/tform_galaxies_hist2.png', dpi = 100, xxbox_inches='tight')

plt.show()

# %% [markdown]
# ## sSFR

# %%
counts_M31gd, bins_M31gd = np.histogram(tf_M31gd, bins=30)
countsb_M31gd, binsb_M31gd = np.histogram(tf_M31gd[mask_M31gd], bins=30)

counts_MWgd, bins_MWgd = np.histogram(tf_MWgd, bins=30)

counts_M33gd, bins_M33gd = np.histogram(tf_M33gd, bins=30)

#-------------------------------------------------------------------------------------
M1, = np.where(r_M31gs>0)
M2, = np.where(r_M31gs[mask_M31gs]>0)

counts_M31gs, bins_M31gs = np.histogram(tf_M31gs[M1], bins=30 )
countsb_M31gs, binsb_M31gs = np.histogram(tf_M31gs[mask_M31gs][M2], bins=30)

M1, = np.where(r_MWgs>0)
M2, = np.where(r_MWgs[mask_MWgs]>0)

counts_MWgs, bins_MWgs = np.histogram(tf_MWgs[M1], bins=30)
countsb_MWgs, binsb_MWgs = np.histogram(tf_MWgs[mask_MWgs][M2], bins=30)

counts_M33gs, bins_M33gs = np.histogram(tf_M33gs, bins=30)

# %%
SFR_M31gd = np.zeros(30)
SFR_MWgd  = np.zeros(30)
SFR_M33gd = np.zeros(30)

SFR_M31gs = np.zeros(30)
SFR_MWgs  = np.zeros(30)
SFR_M33gs = np.zeros(30)

for i in range(30):
    SFR_M31gd[i] = counts_M31gd[i]/(bins_M31gd[i+1]-bins_M31gd[i])
    SFR_MWgd[i]  = counts_MWgd[i] /(bins_MWgd[i+1]-bins_MWgd[i])    
    SFR_M33gd[i] = counts_M33gd[i]/(bins_M33gd[i+1]-bins_M33gd[i])    
    
    SFR_M31gs[i] = counts_M31gs[i]/(bins_M31gs[i+1]-bins_M31gs[i])
    SFR_MWgs[i]  = counts_MWgs[i] /(bins_MWgs[i+1]-bins_MWgs[i])
    SFR_M33gs[i] = counts_M33gs[i]/(bins_M33gs[i+1]-bins_M33gs[i])

# %%
path = '/home/omarioni/'

M31gd  = np.loadtxt(path + 'Barras_GdGs/Barras_Gd/_data/M31_radios.dat')
Mgal_M31gd = M31gd[4]
print Mgal_M31gd

MWgd  = np.loadtxt(path + 'Barras_GdGs/Barras_Gd/_data/MW_radios.dat')
Mgal_MWgd = MWgd[4]

M33gd  = np.loadtxt(path + 'Barras_GdGs/Barras_Gd/_data/M33_radios.dat')
Mgal_M33gd = M33gd[4]

M31gs  = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/M31_radios.dat')
Mgal_M31gs = M31gs[4]
print Mgal_M31gs

MWgs  = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/MW_radios.dat')
Mgal_MWgs = MWgs[4]

M33gs  = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/M33_radios.dat')
Mgal_M33gs = M33gs[4]
# Out:
# 13324700593.948364
# 11138549760.0

# %%
sSFR_M31gd = SFR_M31gd/Mgal_M31gd
sSFR_MWgd  = SFR_MWgd/Mgal_MWgd
sSFR_M33gd = SFR_M33gd/Mgal_M33gd

sSFR_M31gs = SFR_M31gs/Mgal_M31gs
sSFR_MWgs  = SFR_MWgs/Mgal_MWgs
sSFR_M33gs = SFR_M33gs/Mgal_M33gs

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.10, left =0.12, right = 0.97, top = 0.97)

ax.plot(bins_M31gd[1:] ,sSFR_M31gd*1e-9,'-', lw=2.5, color='#801414', label='A-GADGET2')
ax.plot(bins_M31gs[1:] ,sSFR_M31gs*1e-9,'-', lw=2.5, color='#FF0000', label='A-GASOLINE')
# ax.plot(bins_MWgd[1:]  ,sSFR_MWgd*1e-9, '-', lw=2.5, color='#020076', label='B-GADGET2')
# ax.plot(bins_MWgs[1:]  ,sSFR_MWgs*1e-9, '-', lw=2.5, color='#FF963E', label='B-GASOLINE')
# ax.plot(bins_M33gd[1:] ,sSFR_M33gd*1e-9,'-', lw=2.5, color='#5075FE', label='C-GADGET2')
# ax.plot(bins_M33gs[1:] ,sSFR_M33gs*1e-9,'-', lw=2.5, color='#4FBFFF', label='C-GASOLINE')


ax.set_ylabel(r'$\mathrm{sSFR\:[yr^{-1}]}$', fontsize=20)
ax.set_xlabel(r'$\mathrm{t_{form}\:[Gyr]}$',fontsize=20)
ax.set_xticks([0,2,4,6,8,10,12,14])
# ax.yaxis.set_major_locator(MultipleLocator(0.1))
# ax.yaxis.set_major_formatter(NullFormatter())
# ax.set_yticklabels(['','','$0.1$','','$0.3$','','$0.5$','','$0.7$'])
# ax.axes.ticklabel_format(style='sci')
# ax.set_ylim(0,0.7)
ax.set_xlim(0,14)
ax.minorticks_on()
ax.tick_params( labelsize=20)
ax.tick_params('both', length=7, width=1.8,which='minor', direction='in', right='on',top='on')
ax.tick_params('both', length=10, width=1.8,which='major', direction='in', right='on',top='on')
# ax.yaxis.set_minor_locator(MultipleLocator(0.025)) 

ax.legend(fontsize=18,frameon=False, loc=1)

# fig.savefig('/home/omarioni/Barras_GdGs/Barras_Gd/_imagenes/sSFR_time.pdf', dpi = 100, xxbox_inches='tight')

plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('A-Gadget2',fontsize=16)
ax[0].hist(tf_M31gd,histtype='bar',lw=2, color='k' )
ax[0].hist(tf_M31gd[mask_M31gd], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_M31gd), color='k',label='all galaxy')
ax[1].hist(np.log10(r_M31gd[mask_M31gd]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('B-Gadget2',fontsize=16)
ax[0].hist(tf_MWgd,histtype='bar',lw=2, color='k' )
# ax[0].hist(tf_MWgd[mask_M31gd], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_MWgd), color='k',label='all galaxy')
# ax[1].hist(np.log10(r_MWgd[mask_M31gd]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('C-Gadget2',fontsize=16)
ax[0].hist(tf_M33gd,histtype='bar',lw=2, color='k' )
# ax[0].hist(tf_M31gd[mask_M31gd], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_M33gd), color='k',label='all galaxy')
# ax[1].hist(np.log10(r_M31gd[mask_M31gd]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('A-Gasoline',fontsize=16)
ax[0].hist(tf_M31gs,histtype='bar',lw=2, color='k' )
ax[0].hist(tf_M31gs[mask_M31gs], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_M31gs[np.where(r_M31gs>0)]), color='k',label='all galaxy')
ax[1].hist(np.log10(r_M31gs[mask_M31gs][np.where(r_M31gs[mask_M31gs]>0)]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('B-Gasoline',fontsize=16)
ax[0].hist(tf_MWgs,histtype='bar',lw=2, color='k' )
ax[0].hist(tf_MWgs[mask_MWgs], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_MWgs[np.where(r_MWgs>0)]), color='k',label='all galaxy')
ax[1].hist(np.log10(r_MWgs[mask_MWgs][np.where(r_MWgs[mask_MWgs]>0)]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
fig.subplots_adjust(bottom=0.08, left =0.14, right = 0.95, top = 0.95, wspace=.25, hspace= 0)

ax[0].set_title('C-Gasoline',fontsize=16)
ax[0].hist(tf_M33gs,histtype='bar',lw=2, color='k' )
# ax[0].hist(tf_MWgs[mask_MWgs], color='r')
ax[0].set_xlabel('tform', fontsize=16)

ax[1].hist(np.log10(r_M33gs[np.where(r_M33gs>0)]), color='k',label='all galaxy')
# ax[1].hist(np.log10(r_MWgs[mask_MWgs][np.where(r_MWgs[mask_MWgs]>0)]),color='r', label='bar')
ax[1].set_xlabel('log(dist)',fontsize=16)
ax[1].axvline(x=np.log10(15), color='gray', ls='--')
ax[1].legend()
# ax[1].set_xscale('log')

# %% [markdown]
# ## Particulas de la barra (Plot viejo)

# %%
# path = '/home/ornela/PYTHON/'
path = '/home/omarioni/'

M31_gd = np.loadtxt(path + 'Barras_GdGs/Barras_Gd/_data/M31_tform_barra.dat')
M31gd_IDs   = M31_gd[:,0]
M31gd_tform = M31_gd[:,1]
M31gd_rn_z0 = M31_gd[:,2]
M31gd_r_zx  = M31_gd[:,3]
#------------------------------------------------------------------------------------------

M31_gs = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/M31_tform_barra.dat')
M31gs_IDs   = M31_gs[:,0]
M31gs_tform = M31_gs[:,1]
M31gs_rn_z0 = M31_gs[:,2]
M31gs_r_zx  = M31_gs[:,3]
#------------------------------------------------------------------------------------------
MW_gs = np.loadtxt(path + 'Barras_GdGs/Barras_Gs/_data/MW_tform_barra.dat')
MWgs_IDs   = MW_gs[:,0]
MWgs_tform = MW_gs[:,1]
MWgs_rn_z0 = MW_gs[:,2]
MWgs_r_zx  = MW_gs[:,3]

# %%
#In situ --------------------------------------------
M31gd_insitu = 100.*len(M31gd_IDs[np.where(M31gd_r_zx <= 2.5)])/len(M31gd_IDs)
print M31gd_insitu

M31gs_insitu = 100.*len(M31gs_IDs[np.where(M31gs_r_zx <= 2.5)])/len(M31gs_IDs)
print M31gs_insitu

MWgs_insitu = 100.*len(MWgs_IDs[np.where(MWgs_r_zx <= 5.)])/len(MWgs_IDs)
print MWgs_insitu


#Accreted --------------------------------------

M31gd_accreted = 100.*len(M31gd_IDs[np.where(M31gd_r_zx > 2.5)])/len(M31gd_IDs)
print M31gd_accreted

M31gs_accreted = 100.*len(M31gs_IDs[np.where(M31gs_r_zx > 2.5)])/len(M31gs_IDs)
print M31gs_accreted

MWgs_accreted = 100.*len(MWgs_IDs[np.where(MWgs_r_zx > 5.)])/len(MWgs_IDs)
print MWgs_accreted
# Out:
# 93.186446855
# 95.4832382255
# 93.613571508
# 6.81355314496
# 4.51676177447
# 6.38642849201

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16, 16))#, sharey=True, sharex=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.08, left =0.12, right = 0.95, top = 0.95, wspace=0., hspace= 0)

ax[0,0].plot(M31gd_tform ,M31gd_r_zx,'.', markersize=0.1, color='k')
ax[0,0].set_ylabel(r'$d\:[kpc]$', fontsize=40)
ax[0,0].set_xlabel(r'$form\:time\:[Gyr]$', fontsize=40)
ax[0,0].set_xticks([0,2,4,6,8,10,12])
# ax[0,0].set_xticklabels([])
ax[0,0].set_yscale('log')
ax[0,0].set_yticks([0.001,0.01,0.1,1,10,100])
ax[0,0].set_ylim(0.01,500)
ax[0,0].set_xlim(0,14)
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=40)
ax[0,0].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[0,0].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[0,0].axhline(y=2.5, color='k', linestyle='--')
# ax[0,0].text(11, 0.05, 'In situ', fontsize=30, color='k', ha='center', va='center')
# ax[0,0].text(11, 30, 'Accreted', fontsize=30, color='k', ha='center', va='center')
ax[0,0].text(11, 30, 'Accreted '+str('%.1f'%M31gd_accreted)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[0,0].text(3, 0.03, 'In situ '+str('%.1f'%M31gd_insitu)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[0,0].text(12, 250, 'A', fontsize=30, color='k', ha='left', va='center')
ax[0,0].set_title('GADGET', loc='center', fontsize=30)
ax[0,0].fill_between([-1,15],0,0.14, color='k', alpha=0.2)

#------------------------------------------------------

# ax2=fig.add_subplot(222)
ax[0,1].plot(M31gs_tform ,M31gs_r_zx,'.', markersize=0.1, color='k')
ax[0,1].set_xticks([0,2,4,6,8,10,12,14])
ax[0,1].set_xticklabels([])
ax[0,1].set_yticks([0.01,0.1,1,10,100])
ax[0,1].set_yscale('log')
ax[0,1].set_yticklabels([])
ax[0,1].set_ylim(0.01,500)
ax[0,1].set_xlim(0,14)
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=40)
ax[0,1].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[0,1].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[0,1].axhline(y=2.5, color='k', linestyle='--')
ax[0,1].text(12, 250, 'A', fontsize=30, color='k', ha='left', va='center')
ax[0,1].text(11, 30, str('%.1f'%M31gs_accreted)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[0,1].text(3, 0.03, str('%.1f'%M31gs_insitu)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[0,1].set_title('GASOLINE', loc='center', fontsize=30)
ax[0,1].fill_between([-1,15],0,0.22, color='k', alpha=0.2)

# # #---------------------------------------------------------

# ax3=fig.add_subplot(223)
# ax[1,0].plot(time_MWgd ,Mdrk05_MWgd-Mdrk05_MWgd[0],'-', lw=2, color='r')
# ax[1,0].plot(time_MWgd ,Mdrk10_MWgd-Mdrk10_MWgd[0],'-', lw=2, color='b')
# ax[1,0].plot(time_MWgd ,Mdrk15_MWgd-Mdrk15_MWgd[0],'-', lw=3, color='k')

# ax[1,0].set_xticks([0,2,4,6,8,10,12,14])
# ax[1,0].set_xlabel(r'$form\:time\:[Gyr]$', fontsize=40)
# ax[1,0].set_ylabel(r'$d\:[kpc]$', fontsize=40)
# ax[1,0].set_yscale('log')
# ax[1,0].set_yticks([0.01,0.1,1,10,100])
# ax[1,0].set_ylim(0.01,500)
# ax[1,0].set_xlim(0,14)
# ax[1,0].minorticks_on()
# ax[1,0].tick_params( labelsize=40)
# ax[1,0].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
# ax[1,0].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')

# ax[1,0].text(12, 250, 'B', fontsize=30, color='k',ha='left', va='center')
ax[1,0].axis('off')

# # #---------------------------------------------------------------------------------------
# # ax4=fig.add_subplot(224)
ax[1,1].plot(MWgs_tform ,MWgs_r_zx,'.', markersize=0.1, color='k')

ax[1,1].set_xticks([0,2,4,6,8,10,12,14])
ax[1,1].set_xlabel(r'$form\:time\:[Gyr]$', fontsize=40)
ax[1,1].set_ylabel(r'$d\:[kpc]$', fontsize=40)
ax[1,1].set_yticks([0.01,0.1,1,10,100])
ax[1,1].set_yscale('log')
# ax[1,1].set_yticklabels([])
ax[1,1].set_ylim(0.01,500)
ax[1,1].set_xlim(0,14)
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=40)
ax[1,1].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[1,1].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[1,1].axhline(y=5, color='k', linestyle='--')
ax[1,1].text(11, 30, str('%.1f'%MWgs_accreted)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[1,1].text(3, 0.03, str('%.1f'%MWgs_insitu)+r'\%', fontsize=25, color='k', ha='center', va='center')
ax[1,1].text(12, 250, 'B', fontsize=30, color='k', ha='left', va='center')
ax[1,1].fill_between([-1,15],0,0.22, color='k', alpha=0.2)

# fig.savefig('/home/ornela/overleaf/13216980csjxswjndpmj/tform_bar.png', dpi = 100, xxbox_inches='tight')
fig.savefig('/home/omarioni/Barras_GdGs/Barras_Gd/_imagenes/tform_bar.png', dpi = 100, xxbox_inches='tight')

plt.show()
# Out:
# /home/omarioni/.conda/envs/conda-env/lib/python2.7/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(16, 16))#, sharey=True, sharex=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.08, left =0.12, right = 0.95, top = 0.95, wspace=0., hspace= 0)

ax[0,0].plot(M31gd_rn_z0 ,M31gd_r_zx,'.', markersize=0.1, color='k')
ax[0,0].set_ylabel(r'$d\:[kpc]$', fontsize=40)
ax[0,0].set_xticks([0.01,0.1,1])
ax[0,0].set_xscale('log')
ax[0,0].set_xticklabels([])
ax[0,0].set_yscale('log')
ax[0,0].set_yticks([0.001,0.01,0.1,1,10,100])
ax[0,0].set_ylim(0.01,500)
ax[0,0].set_xlim(0.005,2)
ax[0,0].minorticks_on()
ax[0,0].tick_params( labelsize=40)
ax[0,0].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[0,0].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[0,0].axhline(y=2.5, color='r', linestyle='--')
# ax[0,0].text(11, 0.05, 'In situ', fontsize=30, color='r', ha='center', va='center')
# ax[0,0].text(11, 30, 'Accreted', fontsize=30, color='r', ha='center', va='center')
# ax[0,0].text(11, 4, r'\%'+str('%.2f'%M31gd_accreted), fontsize=25, color='r', ha='left', va='center')
# ax[0,0].text(11, 1.5, r'\%'+str('%.2f'%M31gd_insitu), fontsize=25, color='r', ha='left', va='center')
ax[0,0].text(0.008, 250, 'A', fontsize=30, color='k', ha='left', va='center')
ax[0,0].set_title('GADGET', loc='center', fontsize=30)

#------------------------------------------------------

# ax2=fig.add_subplot(222)
ax[0,1].plot(M31gs_rn_z0 ,M31gs_r_zx,'.', markersize=0.1, color='k')
ax[0,1].set_xticks([0.01,0.1,1])
ax[0,1].set_xscale('log')
ax[0,1].set_xticklabels([])
ax[0,1].set_yticks([0.01,0.1,1,10,100])
ax[0,1].set_yscale('log')
ax[0,1].set_yticklabels([])
ax[0,1].set_ylim(0.01,500)
ax[0,1].set_xlim(0.005,2)
ax[0,1].minorticks_on()
ax[0,1].tick_params( labelsize=40)
ax[0,1].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[0,1].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[0,1].axhline(y=2.5, color='r', linestyle='--')
ax[0,1].text(0.008, 250, 'A', fontsize=30, color='k', ha='left', va='center')
# ax[0,1].text(11, 4, r'\%'+str('%.2f'%M31gs_accreted), fontsize=25, color='r', ha='left', va='center')
# ax[0,1].text(11, 1.5, r'\%'+str('%.2f'%M31gs_insitu), fontsize=25, color='r', ha='left', va='center')
ax[0,1].set_title('GASOLINE', loc='center', fontsize=30)

# # #---------------------------------------------------------

# ax3=fig.add_subplot(223)
# ax[1,0].plot(time_MWgd ,Mdrk05_MWgd-Mdrk05_MWgd[0],'-', lw=2, color='r')
# ax[1,0].plot(time_MWgd ,Mdrk10_MWgd-Mdrk10_MWgd[0],'-', lw=2, color='b')
# ax[1,0].plot(time_MWgd ,Mdrk15_MWgd-Mdrk15_MWgd[0],'-', lw=3, color='k')
ax[1,0].set_xticks([0.01,0.1,1])
ax[1,0].set_xscale('log')
ax[1,0].set_xlabel(r'$d_{z=0}\:[kpc]$', fontsize=40)
ax[1,0].set_ylabel(r'$d\:[kpc]$', fontsize=40)
ax[1,0].set_yscale('log')
ax[1,0].set_yticks([0.01,0.1,1,10,100])
ax[1,0].set_ylim(0.01,500)
ax[1,0].set_xlim(0.005,2)
ax[1,0].minorticks_on()
ax[1,0].tick_params( labelsize=40)
ax[1,0].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[1,0].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')

ax[1,0].text(0.008, 250, 'B', fontsize=30, color='k',ha='left', va='center')


# # #---------------------------------------------------------------------------------------
# # ax4=fig.add_subplot(224)
ax[1,1].plot(MWgs_rn_z0 ,MWgs_r_zx,'.', markersize=0.1, color='k')

ax[1,1].set_xticks([0.01,0.1,1])
ax[1,1].set_xscale('log')
ax[1,1].set_xlabel(r'$d_{z=0}\:[Gyr]$', fontsize=40)
ax[1,1].set_yticks([0.01,0.1,1,10,100])
ax[1,1].set_yscale('log')
ax[1,1].set_yticklabels([])
ax[1,1].set_ylim(0.01,500)
ax[1,1].set_xlim(0.005,2)
ax[1,1].minorticks_on()
ax[1,1].tick_params( labelsize=40)
ax[1,1].tick_params('both', length=5, width=1.8,which='minor', direction='in', right='on',top='on')
ax[1,1].tick_params('both', length=8, width=1.8,which='major', direction='in', right='on',top='on')
ax[1,1].axhline(y=5, color='r', linestyle='--')
# ax[1,1].text(11, 8, r'\%'+str('%.2f'%MWgs_accreted), fontsize=25, color='r', ha='left', va='center')
# ax[1,1].text(11, 3, r'\%'+str('%.2f'%MWgs_insitu), fontsize=25, color='r', ha='left', va='center')
ax[1,1].text(0.008, 250, 'B', fontsize=30, color='k', ha='left', va='center')

# fig.savefig('/home/ornela/overleaf/13216980csjxswjndpmj/tform_bar.png', dpi = 100, xxbox_inches='tight')
fig.savefig('/home/omarioni/Barras_GdGs/Barras_Gd/_imagenes/tform_bar2.png', dpi = 100, xxbox_inches='tight')

plt.show()
