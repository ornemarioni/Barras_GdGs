# %% [markdown]
# ## We compared Q of M33 and a mock galaxy

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockM1c.dat')
MockM1b_rbin   = data[:,0]
MockM1b_sigmaz = data[:,1]
MockM1b_sigmaR = data[:,2]
MockM1b_surden = data[:,4]
MockM1b_Vcirc  = data[:,5]
MockM1b_rvc    = data[:,6]
MockM1b_Q      = data[:,7]
MockM1b_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1.dat')
Mockd1_rbin   = data[:,0]
Mockd1_sigmaz = data[:,1]
Mockd1_sigmaR = data[:,2]
Mockd1_surden = data[:,4]
Mockd1_Vcirc  = data[:,5]
Mockd1_rvc    = data[:,6]
Mockd1_Q      = data[:,7]
Mockd1_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1b.dat')
Mockd1b_rbin   = data[:,0]
Mockd1b_sigmaz = data[:,1]
Mockd1b_sigmaR = data[:,2]
Mockd1b_surden = data[:,4]
Mockd1b_Vcirc  = data[:,5]
Mockd1b_rvc    = data[:,6]
Mockd1b_Q      = data[:,7]
Mockd1b_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1c.dat')
Mockd1c_rbin   = data[:,0]
Mockd1c_sigmaz = data[:,1]
Mockd1c_sigmaR = data[:,2]
Mockd1c_surden = data[:,4]
Mockd1c_Vcirc  = data[:,5]
Mockd1c_rvc    = data[:,6]
Mockd1c_Q      = data[:,7]
Mockd1c_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1d.dat')
Mockd1d_rbin   = data[:,0]
Mockd1d_sigmaz = data[:,1]
Mockd1d_sigmaR = data[:,2]
Mockd1d_surden = data[:,4]
Mockd1d_Vcirc  = data[:,5]
Mockd1d_rvc    = data[:,6]
Mockd1d_Q      = data[:,7]
Mockd1d_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1e.dat')
Mockd1e_rbin   = data[:,0]
Mockd1e_sigmaz = data[:,1]
Mockd1e_sigmaR = data[:,2]
Mockd1e_surden = data[:,4]
Mockd1e_Vcirc  = data[:,5]
Mockd1e_rvc    = data[:,6]
Mockd1e_Q      = data[:,7]
Mockd1e_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1f.dat')
Mockd1f_rbin   = data[:,0]
Mockd1f_sigmaz = data[:,1]
Mockd1f_sigmaR = data[:,2]
Mockd1f_surden = data[:,4]
Mockd1f_Vcirc  = data[:,5]
Mockd1f_rvc    = data[:,6]
Mockd1f_Q      = data[:,7]
Mockd1f_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3g.dat')
Mockd3g_rbin   = data[:,0]
Mockd3g_sigmaz = data[:,1]
Mockd3g_sigmaR = data[:,2]
Mockd3g_surden = data[:,4]
Mockd3g_Vcirc  = data[:,5]
Mockd3g_rvc    = data[:,6]
Mockd3g_Q      = data[:,7]
Mockd3g_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'M33GD_test_toomre.dat')
M33GD_rbin   = data[:,0]
M33GD_sigmaz = data[:,1]
M33GD_sigmaR = data[:,2]
M33GD_surden = data[:,4]
M33GD_Vcirc  = data[:,5]
M33GD_Q      = data[:,6]
M33GD_kappa  = data[:,7]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'M33GS_test_toomre.dat')
M33GS_rbin   = data[:,0]
M33GS_sigmaz = data[:,1]
M33GS_sigmaR = data[:,2]
M33GS_surden = data[:,4]
M33GS_Vcirc  = data[:,5]
M33GS_Q      = data[:,6]
M33GS_kappa  = data[:,7]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_Q, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin,  Mockd1b_Q, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_Q,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_Q,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_Q,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_Q,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, Mockd3f_Q,'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, Mockd3g_Q,':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_Q,    '-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_Q,    '-', lw=2.5, color='b', label= 'Gasoline')
ax[0].set_ylim(0,50)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('Q',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_Q/MockM1b_Q,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_Q/MockM1b_Q,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('Qgalaxy / Qmock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_sigmaz, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin, Mockd1b_sigmaz, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_sigmaz,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_sigmaz,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_sigmaz,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_sigmaz,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, Mockd3f_sigmaz,'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, Mockd3g_sigmaz,':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_sigmaz,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_sigmaz,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\sigma_z$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_sigmaz/MockM1b_sigmaz,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_sigmaz/MockM1b_sigmaz,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\sigma_z$_galaxy / $\sigma_z$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_sigmaR, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin, Mockd1b_sigmaR, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_sigmaR,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_sigmaR,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_sigmaR,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_sigmaR,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, Mockd3f_sigmaR,'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, Mockd3g_sigmaR,':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_sigmaR,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_sigmaR,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\sigma_R$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_sigmaR/MockM1b_sigmaR,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_sigmaR/MockM1b_sigmaR,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\sigma_R$_galaxy / $\sigma_R$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  np.log10(MockM1b_surden), '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin,  np.log10(Mockd1b_surden), '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, np.log10(Mockd1c_surden),'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, np.log10(Mockd1d_surden),':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, np.log10(Mockd1e_surden),':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, np.log10(Mockd1f_surden),'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, np.log10(Mockd3f_surden),'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, np.log10(Mockd3g_surden),':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, np.log10(M33GD_surden),'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, np.log10(M33GS_surden),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('log($\Sigma$)',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_surden/MockM1b_surden,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_surden/MockM1b_surden,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('log($\Sigma$_galaxy / $\Sigma$_mock)',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_surden, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin,  Mockd1b_surden, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_surden,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_surden,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_surden,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_surden,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, np.log10(Mockd3f_surden),'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, np.log10(Mockd3g_surden),':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_surden,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_surden,'-', lw=2.5, color='b', label= 'Gasoline')
ax[0].set_ylim(0,0.6e9)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\Sigma$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_surden/MockM1b_surden,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_surden/MockM1b_surden,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\Sigma$_galaxy / $\Sigma$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_Vcirc, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin,  Mockd1b_Vcirc, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_Vcirc,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_Vcirc,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_Vcirc,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_Vcirc,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, Mockd3f_Vcirc,'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, Mockd3g_Vcirc,':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_Vcirc,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_Vcirc,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('Vc',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_Vcirc/MockM1b_Vcirc,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_Vcirc/MockM1b_Vcirc,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('Vc_galaxy / Vc_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  MockM1b_kappa, '-', lw=2.5, color='k', label='M1b')
ax[0].plot(Mockd1b_rbin, Mockd1b_kappa, '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, Mockd1c_kappa,'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, Mockd1d_kappa,':', lw=2.5, color='g', label='D1d')
ax[0].plot(Mockd1e_rbin, Mockd1e_kappa,':',lw=2.5, color='c', label='D1e')
ax[0].plot(Mockd1f_rbin, Mockd1f_kappa,'-', lw=2.5, color='c', label='D1f')
# ax[0].plot(Mockd3f_rbin, Mockd3f_kappa,'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, Mockd3g_kappa,':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, M33GD_kappa,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_kappa,'-', lw=2.5, color='b', label= 'Gasoline')
ax[0].set_ylim(0,100)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\kappa$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_kappa/MockM1b_kappa,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_kappa/MockM1b_kappa,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\kappa$_galaxy / $\kappa$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(MockM1b_rbin,  np.log10(MockM1b_kappa), '-', lw=2.5, color='k', label='M1M')
ax[0].plot(Mockd1b_rbin, np.log10(Mockd1b_kappa), '-', lw=2.5, color='g', label='D1b')
ax[0].plot(Mockd1c_rbin, np.log10(Mockd1c_kappa),'--',lw=2.5, color='g', label='D1c')
ax[0].plot(Mockd1d_rbin, np.log10(Mockd1d_kappa),':', lw=2.5, color='g', label='D1d')
# ax[0].plot(Mockd3d_rbin, np.log10(Mockd3d_kappa),'-.',lw=2.5, color='g', label='D3d')
# ax[0].plot(Mockd3e_rbin, np.log10(Mockd3e_kappa),'-', lw=2.5, color='c', label='D3e')
# ax[0].plot(Mockd3f_rbin, np.log10(Mockd3f_kappa),'--',lw=2.5, color='c', label='D3f')
# ax[0].plot(Mockd3g_rbin, np.log10(Mockd3g_kappa),':', lw=2.5, color='c', label='D3g')
ax[0].plot(M33GD_rbin, np.log10(M33GD_kappa),'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, np.log10(M33GS_kappa),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('log($\kappa$)',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_kappa/MockM1b_kappa,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_kappa/MockM1b_kappa,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\kappa$_galaxy / $\kappa$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()
