# %% [markdown]
# ## We compared Q of M33 and a mock galaxy

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD1.dat')
Mockd1_rbin   = data[:,0]
Mockd1_sigmaz = data[:,1]
Mockd1_sigmaR = data[:,2]
Mockd1_surden = data[:,4]
Mockd1_Vcirc  = data[:,5]
Mockd1_rvc    = data[:,6]
Mockd1_Q      = data[:,7]
Mockd1_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3.dat')
Mockd3_rbin   = data[:,0]
Mockd3_sigmaz = data[:,1]
Mockd3_sigmaR = data[:,2]
Mockd3_surden = data[:,4]
Mockd3_Vcirc  = data[:,5]
Mockd3_rvc    = data[:,6]
Mockd3_Q      = data[:,7]
Mockd3_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3b.dat')
Mockd3b_rbin   = data[:,0]
Mockd3b_sigmaz = data[:,1]
Mockd3b_sigmaR = data[:,2]
Mockd3b_surden = data[:,4]
Mockd3b_Vcirc  = data[:,5]
Mockd3b_rvc    = data[:,6]
Mockd3b_Q      = data[:,7]
Mockd3b_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3c.dat')
Mockd3c_rbin   = data[:,0]
Mockd3c_sigmaz = data[:,1]
Mockd3c_sigmaR = data[:,2]
Mockd3c_surden = data[:,4]
Mockd3c_Vcirc  = data[:,5]
Mockd3c_rvc    = data[:,6]
Mockd3c_Q      = data[:,7]
Mockd3c_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3d.dat')
Mockd3d_rbin   = data[:,0]
Mockd3d_sigmaz = data[:,1]
Mockd3d_sigmaR = data[:,2]
Mockd3d_surden = data[:,4]
Mockd3d_Vcirc  = data[:,5]
Mockd3d_rvc    = data[:,6]
Mockd3d_Q      = data[:,7]
Mockd3d_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3e.dat')
Mockd3e_rbin   = data[:,0]
Mockd3e_sigmaz = data[:,1]
Mockd3e_sigmaR = data[:,2]
Mockd3e_surden = data[:,4]
Mockd3e_Vcirc  = data[:,5]
Mockd3e_rvc    = data[:,6]
Mockd3e_Q      = data[:,7]
Mockd3e_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3f.dat')
Mockd3f_rbin   = data[:,0]
Mockd3f_sigmaz = data[:,1]
Mockd3f_sigmaR = data[:,2]
Mockd3f_surden = data[:,4]
Mockd3f_Vcirc  = data[:,5]
Mockd3f_rvc    = data[:,6]
Mockd3f_Q      = data[:,7]
Mockd3f_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'Q_test_mockD3g.dat')
Mockd3g_rbin   = data[:,0]
Mockd3g_sigmaz = data[:,1]
Mockd3g_sigmaR = data[:,2]
Mockd3g_surden = data[:,4]
Mockd3g_Vcirc  = data[:,5]
Mockd3g_rvc    = data[:,6]
Mockd3g_Q      = data[:,7]
Mockd3g_kappa  = data[:,8]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'M33GD_test_toomre.dat')
M33GD_rbin   = data[:,0]
M33GD_sigmaz = data[:,1]
M33GD_sigmaR = data[:,2]
M33GD_surden = data[:,4]
M33GD_Vcirc  = data[:,5]
M33GD_Q      = data[:,6]
M33GD_kappa  = data[:,7]

# %%
import numpy as np

path = '/home/omarioni/Barras_GdGs/Barras_Gd/_data/Toomre/test/'
data = np.loadtxt(path + 'M33GS_test_toomre.dat')
M33GS_rbin   = data[:,0]
M33GS_sigmaz = data[:,1]
M33GS_sigmaR = data[:,2]
M33GS_surden = data[:,4]
M33GS_Vcirc  = data[:,5]
M33GS_Q      = data[:,6]
M33GS_kappa  = data[:,7]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd1_rbin, Mockd1_Q,'-.', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3_rbin, Mockd3_Q,'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, Mockd3b_Q,'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, Mockd3c_Q,':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3d_rbin, Mockd3d_Q,'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3e_rbin, Mockd3e_Q,'-', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3f_rbin, Mockd3f_Q,'--', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3g_rbin, Mockd3g_Q,':', lw=2.5, color='g', label='Mock')
ax[0].plot(M33GD_rbin, M33GD_Q,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_Q,'-', lw=2.5, color='b', label= 'Gasoline')
ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('Q',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, M33GD_Q/Mock_Q,'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, M33GS_Q/Mock_Q,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('Qgalaxy / Qmock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd3_rbin, Mockd3_sigmaz,'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, Mockd3b_sigmaz,'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, Mockd3c_sigmaz,':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3g_rbin, Mockd3g_sigmaz,'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(M33GD_rbin, M33GD_sigmaz,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_sigmaz,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\sigma_z$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, M33GD_sigmaz/Mock_sigmaz,'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, M33GS_sigmaz/Mock_sigmaz,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\sigma_z$_galaxy / $\sigma_z$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd1_rbin, Mockd1_sigmaR,'-.', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3_rbin, Mockd3_sigmaR,'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, Mockd3b_sigmaR,'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, Mockd3c_sigmaR,':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3d_rbin, Mockd3d_sigmaR,'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3e_rbin, Mockd3e_sigmaR,'-', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3f_rbin, Mockd3f_sigmaR,'--', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3g_rbin, Mockd3g_sigmaR,':', lw=2.5, color='g', label='Mock')
ax[0].plot(M33GD_rbin, M33GD_sigmaR,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_sigmaR,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\sigma_R$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, M33GD_sigmaR/Mock_sigmaR,'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, M33GS_sigmaR/Mock_sigmaR,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\sigma_R$_galaxy / $\sigma_R$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
             
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd1_rbin, np.log10(Mockd1_surden),'-.', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3_rbin, np.log10(Mockd3_surden),'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, np.log10(Mockd3b_surden),'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, np.log10(Mockd3c_surden),':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3d_rbin, np.log10(Mockd3d_surden),'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3e_rbin, np.log10(Mockd3e_surden),'-', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3f_rbin, np.log10(Mockd3f_surden),'--', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3g_rbin, np.log10(Mockd3g_surden),':', lw=2.5, color='g', label='Mock')
ax[0].plot(M33GD_rbin, np.log10(M33GD_surden),'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, np.log10(M33GS_surden),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('log($\Sigma$)',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, np.log10(M33GD_surden/Mock_surden),'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, np.log10(M33GS_surden/Mock_surden),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('log($\Sigma$_galaxy / $\Sigma$_mock)',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd1_rbin, Mockd1_Vcirc,'-.', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3_rbin, Mockd3_Vcirc,'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, Mockd3b_Vcirc,'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, Mockd3c_Vcirc,':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3d_rbin, Mockd3d_Vcirc,'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3e_rbin, Mockd3e_Vcirc,'-', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3f_rbin, Mockd3f_Vcirc,'--', lw=2.5, color='g', label='Mock')
ax[0].plot(Mockd3g_rbin, Mockd3g_Vcirc,':', lw=2.5, color='g', label='Mock')
ax[0].plot(M33GD_rbin, M33GD_Vcirc,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_Vcirc,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('Vc',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, M33GD_Vcirc/Mock_Vcirc,'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, M33GS_Vcirc/Mock_Vcirc,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('Vc_galaxy / Vc_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mock_rbin,  Mock_kappa, '-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockb_rbin,  Mockb_kappa, '--', lw=2.5, color='k', label='Mock')
ax[0].plot(M33GD_rbin, M33GD_kappa,'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, M33GS_kappa,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('$\kappa$',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

ax[1].plot(M33GD_rbin, M33GD_kappa/Mock_kappa,'-', lw=2.5, color='r', label= 'Gadget')
ax[1].plot(M33GS_rbin, M33GS_kappa/Mock_kappa,'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('$\kappa$_galaxy / $\kappa$_mock',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))#,sharey=True
#                        gridspec_kw = {'height_ratios':[3,1,3,1]}
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

ax[0].plot(Mockd3_rbin, np.log10( Mockd3_kappa) ,'-', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3b_rbin, np.log10(Mockd3b_kappa) ,'--', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3c_rbin, np.log10(Mockd3c_kappa) ,':', lw=2.5, color='k', label='Mock')
ax[0].plot(Mockd3g_rbin, np.log10(Mockd3g_kappa) ,'-.', lw=2.5, color='k', label='Mock')
ax[0].plot(M33GD_rbin, np.log10(M33GD_kappa),'-', lw=2.5, color='r', label= 'Gadget')
ax[0].plot(M33GS_rbin, np.log10(M33GS_kappa),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[0].set_ylim(0,5)
ax[0].minorticks_on()
ax[0].tick_params( labelsize=15)
ax[0].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[0].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[0].set_ylabel('log($\kappa$)',fontsize=15)
ax[0].set_xlabel('R [kpc]',fontsize=15)
ax[0].set_xlim(0,15)
ax[0].legend(frameon=False, fontsize=15)

# ax[1].plot(M33GD_rbin, np.log10(M33GD_kappa/Mock_kappa),'-', lw=2.5, color='r', label= 'Gadget')
# ax[1].plot(M33GS_rbin, np.log10(M33GS_kappa/Mock_kappa),'-', lw=2.5, color='b', label= 'Gasoline')
# ax[1].set_ylim(0,5)
ax[1].minorticks_on()
ax[1].tick_params( labelsize=15)
ax[1].tick_params('both', length=5, width=1.2,which='minor', direction='in', right=True,top=True)
ax[1].tick_params('both', length=8, width=1.2,which='major', direction='in', right=True,top=True)
ax[1].set_ylabel('log($\kappa$_galaxy / $\kappa$_mock)',fontsize=15)
ax[1].set_xlabel('R [kpc]',fontsize=15)
ax[1].set_xlim(0,15)
ax[1].legend(frameon=False, fontsize=15)

plt.show()
