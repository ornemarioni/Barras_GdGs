# %% [markdown]
# ### Acá grafico los datos del plot de Algorry et al 2017 con los datos observacionales de Corsini 2011
# ### También voy a agregar los datos observacionales de Font et al 2017 y en el mismo plot ubico mi galaxia

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from __future__ import unicode_literals

matplotlib.rcParams['text.usetex'] = True
matplotlib.rcParams['text.latex.unicode'] = True

cm = np.loadtxt('/home/ornela/PYTHON/Barras_Gd_/barras/lbar_time.dat')
time = cm[:,1]
lbar = cm[:,2]

cm0      = np.loadtxt('/home/ornela/PYTHON/Barras_Gd_/barras/rcorot_phi_time.dat')
time0    = cm0[:,1]
rcor_phi = cm0[:,2]

read    = np.loadtxt('/home/ornela/PYTHON/Barras_Gd/data/datos_corsini.dat')
l_bar   = read[:,0]
lbar_e  = read[:,1]
lbar_er = read[:,2]
rcor    = read[:,3]
rcor_e  = read[:,4]
rcor_er = read[:,5]

read2    = np.loadtxt('/home/ornela/PYTHON/Barras_Gd/data/datos_algorry.dat')
lbar_david = read2[:,0]
rcor_david  = read2[:,1]

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
ax.plot(lbar_david,rcor_david,'s', markersize=10, color='b',alpha=0.7)
# ax.plot(l_bar,rcor,'o', markersize=10, color='gray')
ax.plot([0,50],[0,70], 'k--', lw=2)
ax.plot(lbar[0],rcor_phi[0],'*', markersize=20, color='m')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(0.7,50)
ax.set_ylim(0.7,55)
ax.axvline(50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
ax.minorticks_on()
ax.tick_params( labelsize=22)#, colors='lightgray')
ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')#,colors='w')
ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on')#,colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
#ax.grid(color='lightgray',linestyle=':',which='minor')
ax.set_xlabel(r'$l_{bar}\:[kpc]$', fontsize=30)#, color='lightgray')
ax.set_ylabel(r'$R_{corot}\:[kpc]$',fontsize=30)#, color='lightgray')
ax.text(x = 20, y = 20, s = u'$R_{corot}=1.4\;l_{bar}$', fontsize = 25, rotation= 45,  style='italic',
         verticalalignment = 'center', horizontalalignment = 'center')
ax.errorbar(l_bar,rcor,xerr=[lbar_er,lbar_e], yerr=[rcor_er,rcor_e], color='gray', fmt='o', markersize=10, capsize=3)
# fig.savefig('/home/ornela/Dropbox/Presentaccion_AAA/lbar_time.png', dpi = 100)
ax.text(x = 1, y = 40, s = u'Algorry et al., 2017', fontsize = 20, va = 'bottom', ha = 'left', color='b')
ax.text(x = 1, y = 30, s = u'Corsini, 2011', fontsize = 20, va = 'bottom', ha = 'left', color='grey')
ax.text(x = 1, y = 10, s = u'Slow Bars', fontsize = 30, va = 'bottom', ha = 'left', color='k', style='italic')
ax.text(x = 20, y = 3, s = u'Fast Bars', fontsize = 30, va = 'bottom', ha = 'center',  color='k', style='italic')
plt.show()

# %% [markdown]
# ### Agrego los datos de Font et al 2017

# %%
from matplotlib import cm
cgen = cm.get_cmap(name="Paired")
colors = cgen(np.linspace(0, 1, 3))
colors[0]
# Out:
# array([ 0.65098039,  0.80784314,  0.89019608,  1.        ])

# %%
dist = np.loadtxt('/home/ornela/PYTHON/Barras_Gd/data/Font2017_data/distancia.dat')

ydata = np.loadtxt('/home/ornela/PYTHON/Barras_Gd/data/Font2017_data/rcorot.dat')
rcorot = ydata[:,0]
er_cor = ydata[:,1]

xdata = np.loadtxt('/home/ornela/PYTHON/Barras_Gd/data/Font2017_data/lbar.dat')
lbar_ = xdata[:,0]
er_lbar = xdata[:,1]

conv_rad = pi/(180*3600)
L_bar = lbar_ * dist*1e3 * conv_rad
errorL = er_lbar * dist*1e3 * conv_rad
Rcor = rcorot * dist*1e3 * conv_rad
errorR = er_cor * dist*1e3 * conv_rad

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
ax.plot(lbar_david,rcor_david,'s', markersize=10, color='darkgreen')#,alpha=0.7)
ax.errorbar(L_bar,Rcor,xerr=[errorL,errorL], yerr=[errorR,errorR], color='darkorange', fmt='^', markersize=10, capsize=3)
ax.errorbar(l_bar,rcor,xerr=[lbar_er,lbar_e], yerr=[rcor_er,rcor_e], color='b', fmt='o', markersize=10, capsize=3)
# ax.plot(l_bar,rcor,'o', markersize=10, color='gray')
ax.plot([0,50],[0,70], 'k--', lw=2)
ax.plot(lbar[0],rcor_phi[0],'*', markersize=30, color='r')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlim(0.7,50)
ax.set_ylim(0.7,55)
# ax.axvline(50)
# ax.spines['bottom'].set_color('w')
# ax.spines['top'].set_color('w')
# ax.spines['left'].set_color('w')
# ax.spines['right'].set_color('w')
ax.minorticks_on()
ax.tick_params( labelsize=22)#, colors='lightgray')
ax.tick_params('both', length=3, width=1.2,which='minor', direction='in', right='on',top='on')#,colors='w')
ax.tick_params('both', length=6, width=1.2,which='major', direction='in', right='on',top='on')#,colors='w')  
# ax.set_facecolor('silver')
# ax.grid(color='w',linestyle=':',which='major')
#ax.grid(color='lightgray',linestyle=':',which='minor')
ax.set_xlabel(r'$l_{bar}\:[kpc]$', fontsize=30)#, color='lightgray')
ax.set_ylabel(r'$R_{corot}\:[kpc]$',fontsize=30)#, color='lightgray')
ax.text(x = 27, y = 30, s = u'$R_{corot}=1.4\;l_{bar}$', fontsize = 25, rotation= 45,  style='italic',
         verticalalignment = 'center', horizontalalignment = 'center')
# # fig.savefig('/home/ornela/Dropbox/Presentaccion_AAA/lbar_time.png', dpi = 100)
ax.text(x = 1, y = 40, s = u'Algorry et al., 2017', fontsize = 20, va = 'bottom', ha = 'left', color='darkgreen')
ax.text(x = 1, y = 30, s = u'Corsini, 2011', fontsize = 20, va = 'bottom', ha = 'left', color='darkorange')
ax.text(x = 1, y = 23, s = u'Font et al., 2017', fontsize = 20, va = 'bottom', ha = 'left', color='b')
ax.text(x = 1, y = 10, s = u'Slow Bars', fontsize = 30, va = 'bottom', ha = 'left', color='k', style='italic')
ax.text(x = 20, y = 3, s = u'Fast Bars', fontsize = 30, va = 'bottom', ha = 'center',  color='k', style='italic')
plt.show()
