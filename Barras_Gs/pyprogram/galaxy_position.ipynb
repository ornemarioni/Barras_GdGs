# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pyplot as plt
import h5py
import rotation as rot
import barstrength1 as strng
import kapparot as krot

vector = (1,2,4)
#snapshot = np.loadtxt('/z/dalgorry/snapshots.txt', dtype='string')
#snum = len(snapshot)

#for j in range(snum-1,snum-2,-1):
    #print j, snapshot[j]
snap = h5py.File('../outputs/snap_1024.h5py', 'r')

for i in range(0,3):
    cm   = snap['subhalo_00'+ str('%s' %vector[i])+ '/Center'].value
    aexp = snap['subhalo_00'+ str('%s'%vector[i]) +'/aexp'].value

    pstr = snap['subhalo_00'+ str('%s'%vector[i]) + '/Str/Coordinates'].value

#---aca paso las coordenadas respecto al centro de la galaxia------
    xstr = pstr[:,0]
    ystr = pstr[:,1]
    zstr = pstr[:,2]

    fig=plt.figure(1, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)

    ax1=fig.add_subplot(111)
    ax1.plot(xstr,ystr,'.', markersize=0.1, color = 'k')
    ax1.plot(cm[0],cm[1],'.', markersize=7, color = 'red')
    #ax.set_ylim(-1000,1000)
    #ax.set_xlim(-0.7,0)
    ax1.set_title('Gasoline - StrXY', fontsize=20)
    ax1.set_xlabel(u'$x\;[kpc]$', fontsize=22)
    ax1.set_ylabel(u'$y\;[kpc]$', fontsize=22)
    ax1.minorticks_on()
    ax1.tick_params( labelsize=12)
    ax1.tick_params('both', length=3, width=1.2,which='minor')
    ax1.tick_params('both', length=6, width=1.2,which='major')

    plt.text(x = cm[0]+100, y = cm[1], s = str('%s'%vector[i]), fontsize = 20, 
            verticalalignment = 'center', horizontalalignment = 'center', color = 'r')

    fig=plt.figure(2, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
    ax2=fig.add_subplot(111)
    ax2.plot(xstr,zstr,'.', markersize=0.1, color = 'k')
    ax2.plot(cm[0],cm[2],'.', markersize=7, color = 'red')
    #ax.set_ylim(-1000,1000)
    #ax.set_xlim(-0.7,0)
    ax2.set_title('Gasoline - StrXZ', fontsize=20)
    ax2.set_xlabel(u'$x\;[kpc]$', fontsize=22)
    ax2.set_ylabel(u'$z\;[kpc]$', fontsize=22)
    ax2.minorticks_on()
    ax2.tick_params( labelsize=12)
    ax2.tick_params('both', length=3, width=1.2,which='minor')
    ax2.tick_params('both', length=6, width=1.2,which='major')

    plt.text(x = cm[0]+100, y = cm[2], s = str('%s'%vector[i]), fontsize = 20, 
              verticalalignment = 'center', horizontalalignment = 'center', color = 'r')   


    fig=plt.figure(3, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.16, right = 0.95, top = 0.95)
    ax3=fig.add_subplot(111)
    ax3.plot(ystr,zstr,'.', markersize=0.1, color = 'k')
    ax3.plot(cm[1],cm[2],'.', markersize=7, color = 'red')
    #ax.set_ylim(-1000,1000)
    #ax.set_xlim(-0.7,0)
    ax3.set_title('Gasoline - StrYZ', fontsize=20)
    ax3.set_xlabel(u'$y\;[kpc]$', fontsize=22)
    ax3.set_ylabel(u'$z\;[kpc]$', fontsize=22)
    ax3.minorticks_on()
    ax3.tick_params( labelsize=12)
    ax3.tick_params('both', length=3, width=1.2,which='minor')
    ax3.tick_params('both', length=6, width=1.2,which='major')

    plt.text(x = cm[1]+100, y = cm[2], s = str('%s'%vector[i]), fontsize = 20, 
              verticalalignment = 'center', horizontalalignment = 'center', color = 'r') 
    
plt.show()

# %%
import matplotlib.pyplot as plt
import h5py
import rotation as rot
import barstrength1 as strng
import kapparot as krot

vector = (1,2,4)
vector2 = ('M31','MW','M33')
#snapshot = np.loadtxt('/z/dalgorry/snapshots.txt', dtype='string')
#snum = len(snapshot)

#for j in range(snum-1,snum-2,-1):
    #print j, snapshot[j]
snap = h5py.File('../outputs/snap_1024.h5py', 'r')

for i in range(0,3):
     #cm   = snap['subhalo_00'+ str('%s' %vector[i])+ '/Center'].value
    aexp = snap['subhalo_00'+ str('%s'%vector[i]) +'/aexp'].value
    pstr = snap['subhalo_00'+ str('%s'%vector[i]) + '/Str/Coordinates'].value
    masa_str = snap['subhalo_00'+ str('%s' %vector[i]) + '/Str/Masses'].value
    cm   = snap['subhalo_00'+ str('%s' %vector[i]) + '/Center'].value
    
    cm0   = snap['subhalo_001/Center'].value
    cm1   = snap['subhalo_002/Center'].value
        
    xstr = (pstr[:,0]-cm0[0])*aexp
    ystr = (pstr[:,1]-cm0[1])*aexp
    zstr = (pstr[:,2]-cm0[2])*aexp
    cm = cm*aexp
    cm0 = cm0*aexp
    cm1 = cm1*aexp
    
    d1 = cm[0] - cm0[0]
    d2 = cm[1] - cm0[1]
    d3 = cm[2] - cm0[2]

    dist = np.sqrt(d1**2+d2**2+d3**2)

    d11 = cm[0] - cm1[0]
    d22 = cm[1] - cm1[1]
    d33 = cm[2] - cm1[2]

    dist2 = np.sqrt(d11**2+d22**2+d33**2)
    
    print 'distancia a M31=',dist,'distancia a MW=', dist2
    
    fig=plt.figure(1, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)

    ax1=fig.add_subplot(111)
    ax1.plot(xstr,ystr,'.', markersize=0.1, color = 'k')
    ax1.plot(cm[0]-cm0[0],cm[1]-cm0[1],'.', markersize=7, color = 'red')
    ax1.set_ylim(-1500,1500)
    ax1.set_xlim(-1500,1500)
    #ax1.set_title('Gasoline - StrXY', fontsize=20)
    ax1.set_xlabel(u'$x\;[kpc]$', fontsize=30)
    ax1.set_ylabel(u'$y\;[kpc]$', fontsize=30)
    ax1.minorticks_on()
    ax1.tick_params( labelsize=19)
    ax1.tick_params('both', length=3, width=1.2,which='minor')
    ax1.tick_params('both', length=6, width=1.2,which='major')
    plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='k', ha='left',va='center')
    plt.text(x = cm[0]-cm0[0]+300, y = cm[1]-cm0[1], s =str('%s'%vector2[i]), fontsize = 20, 
               verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
    fig.savefig('/z/dalgorry/plots2/GS_strXY.png', dpi = 100)

    fig=plt.figure(2, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)
    ax2=fig.add_subplot(111)
    ax2.plot(xstr,zstr,'.', markersize=0.1, color = 'k')
    ax2.plot(cm[0]-cm0[0],cm[2]-cm0[2],'.', markersize=7, color = 'red')
    ax2.set_ylim(-1500,1500)
    ax2.set_xlim(-1500,1500)
    #ax2.set_title('Gasoline - StrXZ', fontsize=20)
    ax2.set_xlabel(u'$x\;[kpc]$', fontsize=30)
    ax2.set_ylabel(u'$z\;[kpc]$', fontsize=30)
    ax2.minorticks_on()
    ax2.tick_params( labelsize=19)
    ax2.tick_params('both', length=3, width=1.2,which='minor')
    ax2.tick_params('both', length=6, width=1.2,which='major')
    plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='k', ha='left',va='center')
    plt.text(x = cm[0]-cm0[0]+300, y = cm[2]-cm0[2], s =str('%s'%vector2[i]), fontsize = 20, 
               verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
    fig.savefig('/z/dalgorry/plots2/GS_strXZ.png', dpi = 100)

    fig=plt.figure(3, figsize=(8,8))
    fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)
    ax3=fig.add_subplot(111)
    ax3.plot(ystr,zstr,'.', markersize=0.1, color = 'k')
    ax3.plot(cm[1]-cm0[1],cm[2]-cm0[2],'.', markersize=7, color = 'red')
    ax3.set_ylim(-1500,1500)
    ax3.set_xlim(-1500,1500)
    #ax3.set_title('Gasoline - StrYZ', fontsize=20)
    ax3.set_xlabel(u'$y\;[kpc]$', fontsize=30)
    ax3.set_ylabel(u'$z\;[kpc]$', fontsize=30)
    ax3.minorticks_on()
    ax3.tick_params( labelsize=19)
    ax3.tick_params('both', length=3, width=1.2,which='minor')
    ax3.tick_params('both', length=6, width=1.2,which='major')
    plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='k', ha='left',va='center')
    plt.text(x = cm[1]-cm0[1]+300, y = cm[2]-cm0[2], s = str('%s'%vector2[i]), fontsize = 20, 
                verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
    #fig.savefig('/z/dalgorry/plots2/GS_strYZ.png', dpi = 100)
    
plt.show()
# Out:
# distancia a M31= 0.0 distancia a MW= 1246.30390986
# distancia a M31= 1246.30390986 distancia a MW= 0.0
# distancia a M31= 847.900948173 distancia a MW= 1418.28521545

# %%
#Graficos de Densidad de las Estrellas
import matplotlib.pyplot as plt
import numpy as np
import h5py
import sphviewer as sph

vector = (1,2,4)
vector2 = ('M31','MW','M33')
#snapshot = np.loadtxt('/z/dalgorry/snapshots.txt', dtype='string')
#snum = len(snapshot)

#for j in range(snum-1,snum-2,-1):
    #print j, snapshot[j]
snap = h5py.File('../outputs/snap_1024.h5py', 'r')

xx =[]
yy =[]
zz =[]
masa =[]

for i in range(0,3):
    #cm   = snap['subhalo_00'+ str('%s' %vector[i])+ '/Center'].value
    aexp = snap['subhalo_00'+ str('%s'%vector[i]) +'/aexp'].value
    pstr = snap['subhalo_00'+ str('%s'%vector[i]) + '/Str/Coordinates'].value
    masa_str = snap['subhalo_00'+ str('%s' %vector[i]) + '/Str/Masses'].value
    
    cm0   = snap['subhalo_001/Center'].value
        
    xstr = (pstr[:,0]-cm0[0])*aexp
    ystr = (pstr[:,1]-cm0[1])*aexp
    zstr = (pstr[:,2]-cm0[2])*aexp
    #cm = cm*aexp/h
    #cm0 = cm0*aexp/h

    xx =np.append(xx,xstr)
    yy =np.append(yy,ystr)
    zz =np.append(zz,zstr)

    masa = np.append(masa, masa_str)

    
pos=np.ndarray([3,np.size(xx)])
pos[0,:]=xx
pos[1,:]=yy
pos[2,:]=zz
#---------------------generador del gráfico-----------------
rl=1500    
#corte,=np.where((xstr<rl) & (yn<rl) & (zn<rl) & (xn>-rl) & (yn>-rl) & (zn>-rl))

#-----rango que tiene la escala  de colores-----
vmin=0
vmax=8

# ----escala de colores que te guste (http://matplotlib.org/examples/color/colormaps_reference.html)---
cmap='gnuplot'

#-----grafico-----------

particles=sph.Particles(pos,masa,nb=50)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl])
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()

fig=plt.figure(1, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
plt.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap, vmin=vmin, vmax= vmax)
#ax.plot(xstr,ystr,'.', markersize=0.1, color = 'k')
#ax.plot(cm[0]-cm0[0],cm[1]-cm0[1],'.', markersize=7, color = 'red')
#ax.set_ylim(-1200,1200)
#ax.set_xlim(-1200,1200)
#ax.set_title('sh00', fontsize=22)
#ax.set_title('Gadget - StrXY', fontsize=20)
ax.set_xlabel(u'$x\;[kpc]$', fontsize=30)
ax.set_ylabel(u'$y\;[kpc]$', fontsize=30)
ax.minorticks_on()
ax.tick_params( labelsize=19)
ax.tick_params('both', length=3, width=1.2,which='minor')
ax.tick_params('both', length=6, width=1.2,which='major')
#plt.text(x = cm[0]-cm0[0]+200, y = cm[1]-cm0[1], s =str('%s'%vector2[i]), fontsize = 20, 
#        verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
    #fig.savefig('/home/ornela/Escritorio/seminario2/imagenes/Gadget_strXY.png', dpi = 100)
plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='white', ha='left',va='center')
fig.savefig('/z/dalgorry/plots2/GSd_strXY.png', dpi = 100)

particles=sph.Particles(pos,masa,nb=50)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl], t=90)
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()


fig=plt.figure(2, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
plt.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap, vmin=vmin, vmax= vmax)
#ax.plot(xstr,zstr,'.', markersize=0.1, color = 'k')
#ax.plot(cm[0]-cm0[0],cm[2]-cm0[2],'.', markersize=7, color = 'red')
#ax.set_ylim(-1500,1500)
#ax.set_xlim(-1500,1500)
#ax.set_title('Gadget - StrXZ', fontsize=20)
ax.set_xlabel(u'$x\;[kpc]$', fontsize=30)
ax.set_ylabel(u'$z\;[kpc]$', fontsize=30)
ax.minorticks_on()
ax.tick_params( labelsize=19)
ax.tick_params('both', length=3, width=1.2,which='minor')
ax.tick_params('both', length=6, width=1.2,which='major')
plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='white', ha='left',va='center')
#plt.text(x = cm[0]-cm0[0]+200, y = cm[2]-cm0[2], s =str('%s'%vector2[i]), fontsize = 20, 
       #verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
#fig.savefig('/home/ornela/Escritorio/seminario2/imagenes/Gadget_strXZ.png', dpi = 100)
fig.savefig('/z/dalgorry/plots2/GSd_strXZ.png', dpi = 100)

particles=sph.Particles(pos,masa,nb=50)
escena=sph.Scene(particles)
escena.update_camera(r='infinity',x=0,y=0,z=0,extent=[-rl,rl,-rl,rl], t=90, p=90)
rend=sph.Render(escena)
extent=escena.get_extent()
rend.set_logscale()

fig=plt.figure(3, figsize=(8,8))
fig.subplots_adjust(bottom=0.12, left =0.2, right = 0.95, top = 0.95)
ax=fig.add_subplot(111)
plt.imshow(rend.get_image(),extent=extent,origin='lower',cmap=cmap, vmin=vmin, vmax= vmax)
#ax.plot(ystr,zstr,'.', markersize=0.1, color = 'k')
#ax.plot(cm[1]-cm0[1],cm[2]-cm0[2],'.', markersize=7, color = 'red')
#ax.set_ylim(-1200,1200)
#ax.set_xlim(-1200,1200)
#ax.set_title('Gadget - StrYZ', fontsize=20)
ax.set_xlabel(u'$y\;[kpc]$', fontsize=30)
ax.set_ylabel(u'$z\;[kpc]$', fontsize=30)
ax.minorticks_on()
ax.tick_params( labelsize=19)
ax.tick_params('both', length=3, width=1.2,which='minor')
ax.tick_params('both', length=6, width=1.2,which='major')
plt.text(x=-1400, y=1300, s='GASOLINE',fontsize=22,color='white', ha='left',va='center')
#plt.text(x = cm[1]-cm0[1]+200, y = cm[2]-cm0[2], s = str('%s'%vector2[i]), fontsize = 20, 
#       verticalalignment = 'center', horizontalalignment = 'center', color = 'r')
fig.savefig('/z/dalgorry/plots2/GSd_strYZ.png', dpi = 100)
plt.show()

# %%
import matplotlib.pyplot as plt
import h5py
import rotation as rot
import barstrength1 as strng
import kapparot as krot

vector = (1,2,4)
vector2 = ('M31','MW','M33')
#snapshot = np.loadtxt('/z/dalgorry/snapshots.txt', dtype='string')
#snum = len(snapshot)

#for j in range(snum-1,snum-2,-1):
    #print j, snapshot[j]
snap = h5py.File('../outputs/snap_1024.h5py', 'r')

for i in range(0,3):
    cm   = snap['subhalo_00'+ str('%s' %vector[i])+ '/Center'].value
    aexp = snap['subhalo_00'+ str('%s'%vector[i]) +'/aexp'].value

    pstr = snap['subhalo_00'+ str('%s'%vector[i]) + '/Str/Coordinates'].value

#---aca paso las coordenadas respecto al centro de la galaxia------
    xstr = (pstr[:,0]-cm[0])*aexp
    ystr = (pstr[:,1]-cm[1])*aexp
    zstr = (pstr[:,2]-cm[2])*aexp

    fig=plt.figure(i,figsize=(8,16))
    fig.subplots_adjust(bottom=0.08, left =0.2, right = 0.95, top = 0.95, wspace=0.3, hspace= 0)

    ax1=fig.add_subplot(211)
    ax1.plot(xstr,ystr,'.', markersize=0.1, color = 'k')
    #ax1.plot(cm[0],cm[1],'.', markersize=7, color = 'red')
    ax1.set_ylim(-100,100)
    ax1.set_xlim(-100,100)
    ax1.set_xticklabels([])
    ax1.set_title('Gasoline - '+'%s'%vector2[i], fontsize=20)
    #ax1.set_xlabel(u'$x\;[kpc]$', fontsize=22)
    ax1.set_ylabel(u'$y\;[kpc]$', fontsize=26)
    ax1.minorticks_on()
    ax1.tick_params( labelsize=20)
    ax1.tick_params('both', length=3, width=1.2,which='minor')
    ax1.tick_params('both', length=6, width=1.2,which='major')

    ax2=fig.add_subplot(212)
    ax2.plot(xstr,zstr,'.', markersize=0.1, color = 'k')
    #ax2.plot(cm[0],cm[2],'.', markersize=7, color = 'red')
    ax2.set_ylim(-100,100)
    ax2.set_xlim(-100,100)
    #ax2.set_title('Gasoline - StrXZ', fontsize=20)
    ax2.set_xlabel(u'$x\;[kpc]$', fontsize=26)
    ax2.set_ylabel(u'$z\;[kpc]$', fontsize=26)
    ax2.minorticks_on()
    ax2.tick_params( labelsize=20)
    ax2.tick_params('both', length=3, width=1.2,which='minor')
    ax2.tick_params('both', length=6, width=1.2,which='major')

    #plt.text(x = cm[0]+100, y = cm[2], s = str('%s'%vector2[i]), fontsize = 20, 
    #          verticalalignment = 'center', horizontalalignment = 'center', color = 'r')   
    fig.savefig('/z/dalgorry/plots/Gasoline_'+'%s'%vector2[i]+'.png', dpi = 100)

    
    
plt.show()
